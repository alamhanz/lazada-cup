# %% [markdown]
# # TFIDF transform only with DT

# %%
# https://towardsdatascience.com/multi-label-text-classification-with-scikit-learn-30714b7819c5
# https://docs.google.com/spreadsheets/d/1hg4KKKdivoh6mG7Bena0jYdJSvzgABlWLrU0NX_vHTQ/edit#gid=49385392

# %%
data_path='../../data/'
data_raw_path="../../data/raw/for second propose/"
data_man_path="../../data/manipulate/for second propose/"
model_path="../../model/modeling_second_propose/"

# %%
# %matplotlib inline
import re
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
# from nltk.corpus import stopwords
# stop_words = set(stopwords.words('english'))
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from sklearn.linear_model import SGDClassifier
import seaborn as sns
import nltk
from string import digits
import ast
import itertools

# %%
stop_words=open(data_path+"stopwords_id.txt")
stop_words=list(set([i[:-1] for i in stop_words.readlines()]))

# %%
stop_word_add=['nambah', 'byk', 'yaaa', 'ksh', 'bs', 'kl', 'sm', 'smua',
       'seadanya', 'ajh', 'atau', 'mnta', 'klw', 'ato', 'kalo', 'abis',
       'bnyk', 'pokoknya', 'jgn', 'smuanya', 'klo', 'gitu', 'yaaaa',
       'gpp', 'disitu', 'aj', 'hehe', 'jg', 'yng', 'ya', 'habis', 'gada',
       'ajaa', 'klu', 'ush', 'terserah', 'yah', 'salah', 'brp', 'yaa',
       'aja', 'trs', 'tambahin', 'nya', 'tp', 'ajah', 'mnt', 'situ',
       'segitu', 'disatuin', 'satuin', 'gapapa', 'yg', 'gabung', 'trus',
       'biar', 'nyaa', 'klau', 'lbh']
stop_words2=stop_words+stop_word_add

# %% [markdown]
# # Get The Data

# %%
dtag=pd.read_csv(data_man_path+"data_tag_goshop2.csv").drop_duplicates()
# dtag.to_csv(data_man_path+"data_tag_goshop2.csv",index=False)

# %%
dtext2=pd.read_csv(data_man_path+"data_raw_path_w_label2.csv")
dtext2["real_tags"]=dtext2.real_tags.apply(lambda x : set(ast.literal_eval(x)))

# %%
# dtext2[dtext2.real_tags.apply(lambda x: "kelinci" in x)]

# %%
dtext2["num_tags"]=dtext2.real_tags.apply(lambda x: len(x))

# %%
dtag["num_word"]=dtag.Keywords.apply(lambda x : len(x.split(" ")))
dtag["num_word_tag"]=dtag.Tags.apply(lambda x : len(x.split(" ")))

# %%
keyword_set=set(dtag.Keywords.unique())
keyword_set1=set([t for t in keyword_set if len(t.split(" "))==1])
keyword_set2=set([t for t in keyword_set if len(t.split(" "))==2])
keyword_set3=set([t for t in keyword_set if len(t.split(" "))==3])


ts=set(dtag.Tags.unique())
ts1=set([t for t in ts if len(t.split(" "))==1])
ts2=set([t for t in ts if len(t.split(" "))==2])
ts3=set([t for t in ts if len(t.split(" "))==3])

# %%
dict_keyword=pd.DataFrame(dtag.Tags)
dict_keyword.index=dtag.Keywords
dict_keyword=dict_keyword["Tags"].to_dict()

dict_sc=pd.DataFrame(dtag["Sub-Categories"])
dict_sc.index=dtag.Tags
dict_sc=dict_sc["Sub-Categories"].to_dict()

# %%
print(len(ts1),len(ts2))

# %%
dtext2.sample(100).head(20)

# %%
len(dtext2)

# %% [markdown]
# ### Modeling

# %%
def hamming_score(y_true, y_pred, normalize=True, sample_weight=None):
    '''
    Compute the Hamming score (a.k.a. label-based accuracy) for the multi-label case
    http://stackoverflow.com/q/32239577/395857
    '''
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/float(len(set_true.union(set_pred)) )
        acc_list.append(tmp_a)
    return np.mean(acc_list)


def custom_loss_func2(model,X,y_true0):
    y_pred0=model.predict(X)
    return hamming_score(y_true0, y_pred0)


def print_score(y_pred, clf,y_test_tfidf):
    print("Clf: ", clf)
    print("Hamming loss: {}".format(hamming_loss(y_test_tfidf,y_pred)))
    try:
        print("Hamming score: {}".format(hamming_score(y_test_tfidf,y_pred)))
    except:
        print("Hamming score: {}".format(hamming_score(y_test_tfidf,y_pred.toarray())))
        
    print("---")    
    
def check_tag2(list_X,i):
    if i in list_X:
        return 1
    else :
        return 0

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from imblearn.over_sampling import RandomOverSampler,SMOTE
from sklearn.metrics import hamming_loss
from sklearn.preprocessing import LabelEncoder
from skmultilearn.problem_transform import LabelPowerset,ClassifierChain
from skmultilearn.adapt import MLkNN
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from gensim.models import Word2Vec
from gensim.models.wrappers import FastText
from gensim.models import KeyedVectors
from collections import defaultdict
from sklearn.preprocessing import RobustScaler

# %%
w2v_path="../../data/w2v/"

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    
    stems =[]
    for t in filtered_tokens:
        try:
            t2=stemmer.stem(t.decode("utf-8")) 
        except:
            t2=stemmer.stem(t) 
        stems.append(t2)
        
    return stems
#     return filtered_tokens

# %%
class TfidfEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.word2weight = 1
        self.dim = len(word2vec["buku"])

    def fit(self, X, y=None):
        tfidf = TfidfVectorizer(max_df=0.998, max_features=1500,min_df=0.00005, stop_words='bahasa',
                        use_idf=True, ngram_range=(1,4))
        tfidf.fit(X)
        self.tfidf=tfidf
        # if a word was never seen - it must be at least as infrequent
        # as any of the known words - so the default idf is the max of 
        # known idf's
        max_idf = max(tfidf.idf_)
        self.word2weight = defaultdict(
            lambda: max_idf,
            [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()])

        return self

    def transform(self, X):
        return np.array([
                np.mean([self.word2vec[w] * self.word2weight[w]
                         for w in words.split(" ") if w in self.word2vec] or
                        [np.zeros(self.dim)], axis=0)
                for words in X
            ])

# %%
# embd2=Word2Vec.load(w2v_path+'our_vocab.bin')
embd2=Word2Vec.load(w2v_path+'our_vocab2.bin')

# %%
len(embd2["buku"])

# %%
## remove zero tags
dtext3=dtext2[dtext2.num_tags!=0]
dtext3.head()

# %%
len(dtext3)

# %%
multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(dtext3.real_tags)

# %%
joblib.dump(multilabel_binarizer,model_path+"multilabel_bin_for_dectree.pkl")

# %%
# multilabel_binarizer.classes_

# %%
train2, test2 = train_test_split(dtext3.sample(1450000,random_state=231), random_state=42, test_size=0.2, shuffle=True)

X_train2=train2.item_list_cln2
X_test2=test2.item_list_cln2

Y_train2=multilabel_binarizer.transform(train2.real_tags)
Y_test2=multilabel_binarizer.transform(test2.real_tags)

# %%
tfidf_only = TfidfVectorizer(max_df=0.9998, max_features=1500,min_df=0.00005, stop_words='bahasa',
                        use_idf=True, ngram_range=(1,4))

tfidf_only.fit(X_train2)

# %%
joblib.dump(tfidf_only,model_path+"tfidf_only_for_dectree.pkl")

# %%
X_tr2=tfidf_only.transform(X_train2)
X_te2=tfidf_only.transform(X_test2)

# %%
X_tr2.shape

# %%
model_path

# %%
Y_train2.shape

# %%
# nb_clf = OneVsRestClassifier(MultinomialNB())
# nb_clf2 = LabelPowerset(MultinomialNB())
# nb_clf3 = ClassifierChain(MultinomialNB())
# sgd = OneVsRestClassifier(SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=6, tol=None))
# lr = OneVsRestClassifier(LogisticRegression())
# lsv = OneVsRestClassifier(LinearSVC())
# MLk = MLkNN(k=20)
# dect = OneVsRestClassifier(DecisionTreeClassifier(max_depth=50, min_samples_split=3, min_samples_leaf=4))
# dect2 = ClassifierChain(DecisionTreeClassifier(max_depth=50, min_samples_split=3, min_samples_leaf=4))
    
clf=OneVsRestClassifier(DecisionTreeClassifier(max_depth=45, min_samples_split=3, min_samples_leaf=4),n_jobs=-1)
print("Fitting ..")
clf.fit(X_tr2, Y_train2)
print("Done!!")
print("Saving..")
joblib.dump(clf,model_path+"dectree_tfidf.pkl")
print("Done!!")


y_pred = clf.predict(X_te2)
print_score(y_pred, clf, Y_test2)
# Out:
# Fitting ..
# Done!!
# Saving..
# Done!!
# Clf:  OneVsRestClassifier(estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=45,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=3,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           n_jobs=-1)
# Hamming loss: 0.00023093464403655634
# Hamming score: 0.9534828502388416
# ---

# %%
## DecTree
clf2=joblib.load(model_path+"dectree_tfidf.pkl")
y_pred2=clf2.predict(X_te2)
test2["tag_pred"]=multilabel_binarizer.inverse_transform(y_pred2)

# %%
hamming_score(Y_test2, y_pred2)

# %%
test2.sample(300).head(20)
# Out:
#                 booking_time   order_no  voucher_id  \
# 462718   2018-01-23 03:45:09  430363640         NaN
# 220444   2018-02-08 05:38:30  438391903         NaN
# 905504   2018-04-28 07:37:55  475563253         NaN
# 1491402  2017-08-04 07:23:16  347459838         NaN
# 202478   2017-06-17 14:10:48  326870090         NaN
# 1268012  2017-12-29 13:21:17  417586843         NaN
# 1515478  2017-10-30 00:08:49  384415541         NaN
# 403018   2017-07-21 04:55:06  342503612         NaN
# 257554   2017-12-26 07:55:30  415846901         NaN
# 156081   2018-03-16 02:50:02  457638559         NaN
# 1108254  2016-04-30 15:43:32  131675547         NaN
# 423858   2017-01-03 11:29:28  278199179         NaN
# 69721    2018-05-01 15:16:38  476341979         NaN
# 141238   2018-01-13 05:14:33  425458235         NaN
# 352639   2018-03-06 06:36:17  452125881         NaN
# 1152415  2017-10-07 03:28:34  373106082         NaN
# 55739    2017-12-30 16:29:08  418235805         NaN
# 1403362  2017-06-23 03:14:31  329702915         NaN
# 1141886  2016-02-02 10:30:06   89853990         NaN
# 1873259  2016-03-20 13:19:02  111642456         NaN
#
#                                                  item_list  \
# 462718                                              pempek
# 220444   seblak seafood,fishrool,otak otak singapure, t...
# 905504                                    mie ayam ceker 2
# 1491402            bumbu rujak tut ting no hp 082237401515
# 202478   martabak spektakuler depan pasar boyolali. Tol...
# 1268012                       pampers mamy poko ukuran XXL
# 1515478    pecel gudeg nasi 1/2 pakai ayam dan telur rebus
# 403018   nasi putih campur jakarta 2, nasi hainam campu...
# 257554   ayam bakar kota = 2jus jeruk = 1bakso goreng k...
# 156081                    Kopi Nescafe Gold (ukuran besar)
# 1108254  paru goreng 2tumis ciwis 1ayam goreng 1sambel ...
# 423858   4 porsi bakso tanpa mie, 1 porsi bakso pke mie...
# 69721                                 anggur merah 2 botol
# 141238                         kue bandung diberi susu aja
# 352639                             Bakso urat enam bungkus
# 1152415  nasi pecel 4 porsi (bumbu dipisah)ikannya telo...
# 55739    anggur merah orang tua 4 plastik kalo bisa car...
# 1403362                                             pempek
# 1141886   Liquid South Cost Vapor - Strawberry Cheese cake
# 1873259  roti pisang 2 ,donat 1, roti sosis 2, pisang c...
#
#         payment_method_name  \
# 462718                 CASH
# 220444                 CASH
# 905504                 CASH
# 1491402                CASH
# 202478                 CASH
# 1268012                CASH
# 1515478                CASH
# 403018                 CASH
# 257554                 CASH
# 156081               GO-PAY
# 1108254                CASH
# 423858                 CASH
# 69721                  CASH
# 141238               GO-PAY
# 352639                 CASH
# 1152415     PARTIAL_PAYMENT
# 55739                  CASH
# 1403362                CASH
# 1141886                CASH
# 1873259                CASH
#
#                                             item_list_cln1  \
# 462718                                              pempek
# 220444   seblak seafood,fishrool,otak otak singapure, t...
# 905504                                      mie ayam ceker
# 1491402                         bumbu rujak tut ting no hp
# 202478   martabak spektakuler depan pasar boyolali, tol...
# 1268012                       pampers mamy poko ukuran xxl
# 1515478            pecel gudeg nasi pakai ayam,telur rebus
# 403018   nasi putih campur jakarta , nasi hainam campur...
# 257554   ayam bakar kota jus jeruk bakso goreng kremes ...
# 156081                      kopi nescafe gold ukuran besar
# 1108254  paru goreng tumis ciwis ayam goreng sambel yg ...
# 423858   porsi bakso tanpa mie, porsi bakso pke mie, ti...
# 69721                                   anggur merah botol
# 141238                         kue bandung diberi susu aja
# 352639                             bakso urat enam bungkus
# 1152415  nasi pecel porsi bumbu dipisah ikannya telor t...
# 55739    anggur merah orang tua plastik kalo bisa cari ...
# 1403362                                             pempek
# 1141886   liquid south cost vapor , strawberry cheese cake
# 1873259  roti pisang ,donat , roti sosis , pisang cokla...
#
#                                             item_list_cln2  \
# 462718                                              pempek
# 220444   seblak seafood fishrool otak otak singapure te...
# 905504                                      mie ayam ceker
# 1491402                         bumbu rujak tut ting no hp
# 202478   martabak spektakuler depan pasar boyolali tolo...
# 1268012                       pampers mamy poko ukuran xxl
# 1515478            pecel gudeg nasi pakai ayam telur rebus
# 403018   nasi putih campur jakarta nasi hainam campur j...
# 257554   ayam bakar kota jus jeruk bakso goreng kremes ...
# 156081                      kopi nescafe gold ukuran besar
# 1108254  paru goreng tumis ciwis ayam goreng sambel yg ...
# 423858   porsi bakso tanpa mie porsi bakso pke mie tida...
# 69721                                   anggur merah botol
# 141238                         kue bandung diberi susu aja
# 352639                             bakso urat enam bungkus
# 1152415  nasi pecel porsi bumbu dipisah ikannya telor t...
# 55739    anggur merah orang tua plastik kalo bisa cari ...
# 1403362                                             pempek
# 1141886     liquid south cost vapor strawberry cheese cake
# 1873259  roti pisang donat roti sosis pisang coklat kro...
#
#                                                  real_tags  num_tags  \
# 462718                                            {pempek}         1
# 220444   {seblak, telur, batagor, otak otak, bawang gor...         5
# 905504                                   {mie ayam, ceker}         2
# 1491402                                            {rujak}         1
# 202478                   {martabak manis, telur, martabak}         3
# 1268012                               {pampers, mamy poko}         2
# 1515478                  {gudeg, nasi, telur, pecel, ayam}         5
# 403018                          {nasi, hainam, nasi putih}         3
# 257554   {jeruk, nasi putih, jus mangga, tempe, ayam ba...         8
# 156081                                              {kopi}         1
# 1108254                             {ayam goreng, tongkol}         2
# 423858                                        {bakso, mie}         2
# 69721                                       {anggur merah}         1
# 141238                                         {susu, kue}         2
# 352639                                        {bakso urat}         1
# 1152415                  {tempe, sayur, telur, nasi pecel}         4
# 55739                                       {anggur merah}         1
# 1403362                                           {pempek}         1
# 1141886                                              {kue}         1
# 1873259      {cokelat, donut, roti, sosis, pisang, pastel}         6
#
#                                                   tag_pred
# 462718                                           (pempek,)
# 220444             (batagor, bawang goreng, seblak, telur)
# 905504                                   (ceker, mie ayam)
# 1491402                                           (rujak,)
# 202478                   (martabak, martabak manis, telur)
# 1268012                               (mamy poko, pampers)
# 1515478                  (ayam, gudeg, nasi, pecel, telur)
# 403018                          (hainam, nasi, nasi putih)
# 257554   (ayam bakar, bakso goreng, jamur, jeruk, jus, ...
# 156081                                             (kopi,)
# 1108254                             (ayam goreng, tongkol)
# 423858                                        (bakso, mie)
# 69721                                      (anggur merah,)
# 141238                                         (kue, susu)
# 352639                                       (bakso urat,)
# 1152415                  (nasi pecel, sayur, telur, tempe)
# 55739                                      (anggur merah,)
# 1403362                                          (pempek,)
# 1141886                                             (kue,)
# 1873259      (cokelat, donut, pastel, pisang, roti, sosis)

# %%
test1=test2[["item_list_cln2","real_tags","tag_pred"]]

# %%
for c in ts:
    cek_tag=test1.real_tags.apply(lambda x : check_tag2(x,c))
    test1[c]=cek_tag
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
acc=[]
benc=[]
lrate=[]
auc_list=[]
for category in list(ts):
    # compute the testing accuracy
    True_tag=test2.real_tags.apply(lambda x: check_tag2(x,category)).as_matrix()
    Pred_tag=test2.tag_pred.apply(lambda x: check_tag2(x,category)).as_matrix()
    
    acc_score=accuracy_score(True_tag,Pred_tag)
    try:
        auc_cat=roc_auc_score(True_tag,Pred_tag)
    except:
        auc_cat=0.001
    
    print('Test accuracy is {}'.format(acc_score))
    if True_tag.mean()<0.5:
        benchm=1-test1[category].mean()
    else:
        benchm=test1[category].mean()
    print('diff with benchmark {}'.format(acc_score-benchm))
    
    acc.append(acc_score)
    benc.append(benchm)
    lrate.append(((acc_score-benchm)/float(benchm))*100)
    auc_list.append(auc_cat)
    
dFRes2=pd.DataFrame({"tags":list(ts),"accuracy":acc,"benchmark":benc,"AUC":auc_list,"learn_rate(%)":lrate})
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.9999034482758621
# diff with benchmark 0.0026482758620689495
# Test accuracy is 1.0
# diff with benchmark 0.0014620689655172603
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.0016827586206896727
# Test accuracy is 1.0
# diff with benchmark 0.0014206896551723913
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0024896551724137295
# Test accuracy is 0.9997586206896552
# diff with benchmark 1.0344827586217242e-05
# Test accuracy is 0.9948206896551725
# diff with benchmark 0.08164482758620695
# Test accuracy is 0.9972275862068966
# diff with benchmark 0.030393103448275838
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0017448275862068652
# Test accuracy is 0.9998310344827587
# diff with benchmark -1.3793103448178634e-05
# Test accuracy is 0.9998379310344827
# diff with benchmark 0.0022999999999999687
# Test accuracy is 0.9997068965517242
# diff with benchmark 0.004720689655172472
# Test accuracy is 1.0
# diff with benchmark 0.0008551724137930705
# Test accuracy is 0.9983413793103448
# diff with benchmark 0.003927586206896594
# Test accuracy is 0.9999448275862068
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.002527586206896526
# Test accuracy is 0.9998827586206896
# diff with benchmark 0.0005896551724138277
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0012068965517241237
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.0012482758620689927
# Test accuracy is 1.0
# diff with benchmark 0.003327586206896549
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.0008103448275862402
# Test accuracy is 0.9998655172413793
# diff with benchmark 0.004810344827586133
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0011275862068965692
# Test accuracy is 0.9998482758620689
# diff with benchmark 0.0022965517241378963
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0019034482758620852
# Test accuracy is 0.9999
# diff with benchmark 0.0
# Test accuracy is 0.9998724137931034
# diff with benchmark 0.0
# Test accuracy is 0.9991896551724138
# diff with benchmark 0.0019413793103447707
# Test accuracy is 0.9993551724137931
# diff with benchmark 0.0024482758620689715
# Test accuracy is 1.0
# diff with benchmark 0.005172413793103403
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0
# Test accuracy is 0.9999068965517242
# diff with benchmark 0.0008793103448275774
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.006255172413793031
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0018896551724137955
# Test accuracy is 0.9996793103448276
# diff with benchmark 0.009065517241379273
# Test accuracy is 0.9997379310344827
# diff with benchmark 6.896551724144828e-06
# Test accuracy is 0.9994551724137931
# diff with benchmark -3.448275862072414e-06
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.002327586206896548
# Test accuracy is 1.0
# diff with benchmark 0.0014896551724138396
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.004058620689655235
# Test accuracy is 0.9998724137931034
# diff with benchmark 0.0028137931034483143
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9986275862068965
# diff with benchmark 0.006017241379310256
# Test accuracy is 0.9998310344827587
# diff with benchmark 4.137931034486897e-05
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0019034482758620852
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.001234482758620703
# Test accuracy is 0.9999172413793104
# diff with benchmark 3.448275862072414e-05
# Test accuracy is 0.9985551724137931
# diff with benchmark 0.026006896551724168
# Test accuracy is 0.9998724137931034
# diff with benchmark 0.00022068965517241246
# Test accuracy is 0.9999172413793104
# diff with benchmark -1.0344827586217242e-05
# Test accuracy is 0.9993103448275862
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0019172413793103749
# Test accuracy is 0.9990172413793104
# diff with benchmark -6.551724137926485e-05
# Test accuracy is 0.9998862068965517
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.008406896551724108
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0023793103448276343
# Test accuracy is 0.9996137931034482
# diff with benchmark 0.002058620689655122
# Test accuracy is 1.0
# diff with benchmark 0.0026827586206896736
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.0026724137931034564
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.004679310344827603
# Test accuracy is 0.9999586206896551
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0009482758620689147
# Test accuracy is 0.9999
# diff with benchmark 1.724137931036207e-05
# Test accuracy is 0.9993241379310345
# diff with benchmark 0.008289655172413757
# Test accuracy is 0.9998103448275862
# diff with benchmark 0.001793103448275879
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.004537931034482745
# Test accuracy is 0.9999586206896551
# diff with benchmark 0.0024724137931033674
# Test accuracy is 0.9996172413793103
# diff with benchmark 0.0020413793103447597
# Test accuracy is 0.9995896551724138
# diff with benchmark 0.0019655172413793887
# Test accuracy is 0.993651724137931
# diff with benchmark 0.06866896551724133
# Test accuracy is 0.9997793103448276
# diff with benchmark 0.006213793103448273
# Test accuracy is 0.9994275862068965
# diff with benchmark -1.724137931036207e-05
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.0035413793103448166
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0021241379310344977
# Test accuracy is 0.9995103448275862
# diff with benchmark 2.0689655172323462e-05
# Test accuracy is 0.9999344827586207
# diff with benchmark 0.0034758620689655517
# Test accuracy is 0.9999413793103449
# diff with benchmark 0.0017068965517241796
# Test accuracy is 0.9997724137931034
# diff with benchmark -6.896551724144828e-06
# Test accuracy is 1.0
# diff with benchmark 0.0018137931034483135
# Test accuracy is 1.0
# diff with benchmark 0.004451724137931046
# Test accuracy is 0.9999413793103449
# diff with benchmark 0.0016275862068966251
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.00014482758620681935
# Test accuracy is 0.9999482758620689
# diff with benchmark 0.00350344827586202
# Test accuracy is 1.0
# diff with benchmark 0.0036931034482758918
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0035310344827585993
# Test accuracy is 0.999951724137931
# diff with benchmark 0.0
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.004310344827586188
# Test accuracy is 0.9999620689655172
# diff with benchmark 0.003803448275861987
# Test accuracy is 0.9993758620689656
# diff with benchmark -1.3793103448178634e-05
# Test accuracy is 1.0
# diff with benchmark 0.003268965517241429
# Test accuracy is 1.0
# diff with benchmark 0.0016655172413793107
# Test accuracy is 0.999303448275862
# diff with benchmark 0.0007241379310344298
# Test accuracy is 0.9995793103448276
# diff with benchmark 6.896551724144828e-06
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.004265517241379246
# Test accuracy is 0.9997586206896552
# diff with benchmark 0.004448275862068973
# Test accuracy is 0.9999103448275862
# diff with benchmark 0.032689655172413845
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.006713793103448218
# Test accuracy is 0.9999206896551724
# diff with benchmark 0.012627586206896635
# Test accuracy is 1.0
# diff with benchmark 0.0019896551724137845
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.0012620689655171713
# Test accuracy is 0.9998482758620689
# diff with benchmark -6.896551724144828e-06
# Test accuracy is 0.9999344827586207
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 1.0
# diff with benchmark 0.001510344827586163
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0029241379310345206
# Test accuracy is 1.0
# diff with benchmark 0.0013620689655172713
# Test accuracy is 0.9995103448275862
# diff with benchmark 0.003917241379310266
# Test accuracy is 0.9998931034482759
# diff with benchmark 0.0020310344827586535
# Test accuracy is 0.9998551724137931
# diff with benchmark 0.0019724137931034225
# Test accuracy is 0.9999931034482759
# diff with benchmark 6.896551724144828e-06
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0013413793103448368
# Test accuracy is 0.9996172413793103
# diff with benchmark 0.00023103448275851868
# Test accuracy is 0.9991310344827586
# diff with benchmark 0.00250344827586213
# Test accuracy is 1.0
# diff with benchmark 0.001234482758620703
# Test accuracy is 0.9998965517241379
# diff with benchmark 0.0
# Test accuracy is 0.9993448275862069
# diff with benchmark 0.008341379310344843
# Test accuracy is 0.9996448275862069
# diff with benchmark -1.3793103448289656e-05
# Test accuracy is 0.9998068965517242
# diff with benchmark 0.00749655172413799
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.001834482758620637
# Test accuracy is 0.9998655172413793
# diff with benchmark 0.0003620689655172704
# Test accuracy is 1.0
# diff with benchmark 0.0014551724137931155
# Test accuracy is 1.0
# diff with benchmark 0.006158620689655225
# Test accuracy is 1.0
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0018206896551724583
# Test accuracy is 1.0
# diff with benchmark 0.001675862068965528
# Test accuracy is 0.9998896551724138
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 0.9998724137931034
# diff with benchmark -6.896551724144828e-06
# Test accuracy is 0.9993827586206897
# diff with benchmark 0.003927586206896594
# Test accuracy is 0.9998137931034483
# diff with benchmark 9.655172413791657e-05
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.0024413793103448267
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.0
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0010620689655171933
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.003527586206896527
# Test accuracy is 1.0
# diff with benchmark 0.002217241379310342
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.002644827586206877
# Test accuracy is 1.0
# diff with benchmark 0.0027413793103447937
# Test accuracy is 0.9999241379310345
# diff with benchmark 0.0390172413793104
# Test accuracy is 1.0
# diff with benchmark 0.001417241379310319
# Test accuracy is 1.0
# diff with benchmark 0.0012137931034482685
# Test accuracy is 0.9999206896551724
# diff with benchmark 0.0
# Test accuracy is 0.9999206896551724
# diff with benchmark 0.00617931034482766
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0020655172413792666
# Test accuracy is 1.0
# diff with benchmark 0.0010275862068965802
# Test accuracy is 1.0
# diff with benchmark 0.0008620689655172153
# Test accuracy is 0.9999689655172413
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 0.999651724137931
# diff with benchmark 0.0007862068965517333
# Test accuracy is 0.9999758620689655
# diff with benchmark 0.007717241379310291
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0012068965517241237
# Test accuracy is 0.9993103448275862
# diff with benchmark 0.0001310344827586407
# Test accuracy is 0.9998103448275862
# diff with benchmark 0.0033137931034482593
# Test accuracy is 0.9999068965517242
# diff with benchmark 0.0049172413793103775
# Test accuracy is 0.9998689655172414
# diff with benchmark 0.0
# Test accuracy is 0.9998896551724138
# diff with benchmark 0.00018965517241376073
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.0038413793103447835
# Test accuracy is 0.999751724137931
# diff with benchmark 0.0005344827586206691
# Test accuracy is 0.999851724137931
# diff with benchmark -3.448275862072414e-06
# Test accuracy is 0.9999034482758621
# diff with benchmark 0.0071103448275862124
# Test accuracy is 0.9986379310344827
# diff with benchmark 0.0010068965517241457
# Test accuracy is 0.9994689655172414
# diff with benchmark 0.0065689655172413985
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.002444827586206899
# Test accuracy is 0.9996448275862069
# diff with benchmark 0.00241724137931032
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.007244827586206926
# Test accuracy is 1.0
# diff with benchmark 0.0034448275862069
# Test accuracy is 1.0
# diff with benchmark 0.002262068965517283
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0009551724137930595
# Test accuracy is 1.0
# diff with benchmark 0.0038344827586206387
# Test accuracy is 0.9994
# diff with benchmark 0.008131034482758537
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.004362068965517274
# Test accuracy is 0.9999206896551724
# diff with benchmark 0.0
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0
# Test accuracy is 0.999851724137931
# diff with benchmark 6.551724137926485e-05
# Test accuracy is 0.9999241379310345
# diff with benchmark 0.001927586206896592
# Test accuracy is 1.0
# diff with benchmark 0.0013620689655172713
# Test accuracy is 1.0
# diff with benchmark 0.0015034482758620182
# Test accuracy is 0.9998827586206896
# diff with benchmark 0.0
# Test accuracy is 0.9999931034482759
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 0.998944827586207
# diff with benchmark 0.01057931034482762
# Test accuracy is 0.9999137931034483
# diff with benchmark 0.0017862068965517341
# Test accuracy is 1.0
# diff with benchmark 0.0015862068965517562
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0018896551724137955
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0012551724137931375
# Test accuracy is 0.9997068965517242
# diff with benchmark 0.0033000000000000806
# Test accuracy is 0.9998827586206896
# diff with benchmark 0.007372413793103494
# Test accuracy is 0.9989758620689655
# diff with benchmark 0.021155172413793055
# Test accuracy is 0.9983655172413793
# diff with benchmark -9.310344827584416e-05
# Test accuracy is 0.999551724137931
# diff with benchmark 0.004793103448275882
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.001310344827586185
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.0022965517241378963
# Test accuracy is 1.0
# diff with benchmark 0.003755172413793084
# Test accuracy is 1.0
# diff with benchmark 0.0010448275862069423
# Test accuracy is 1.0
# diff with benchmark 0.006648275862068953
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.004824137931034422
# Test accuracy is 0.999551724137931
# diff with benchmark 0.0065517241379310365
# Test accuracy is 0.9995689655172414
# diff with benchmark -2.41379310345069e-05
# Test accuracy is 1.0
# diff with benchmark 0.0016068965517241907
# Test accuracy is 0.9999724137931034
# diff with benchmark -3.448275862072414e-06
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.001251724137930954
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0027172413793102868
# Test accuracy is 0.9998793103448276
# diff with benchmark 0.008731034482758582
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.0029379310344828102
# Test accuracy is 1.0
# diff with benchmark 0.0010379310344827974
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0023137931034482584
# Test accuracy is 0.9997862068965517
# diff with benchmark 0.0007206896551724684
# Test accuracy is 1.0
# diff with benchmark 0.0059517241379309915
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.012003448275862083
# Test accuracy is 1.0
# diff with benchmark 0.001434482758620681
# Test accuracy is 0.9997448275862069
# diff with benchmark 0.0028896551724137964
# Test accuracy is 0.9997448275862069
# diff with benchmark 0.008420689655172398
# Test accuracy is 0.9995655172413793
# diff with benchmark 0.01696206896551722
# Test accuracy is 0.9993551724137931
# diff with benchmark 0.00250344827586213
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0
# Test accuracy is 0.9997275862068965
# diff with benchmark 0.0019724137931034225
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0012620689655172823
# Test accuracy is 0.9997758620689655
# diff with benchmark 0.000734482758620647
# Test accuracy is 0.9998310344827587
# diff with benchmark 0.0062517241379310695
# Test accuracy is 1.0
# diff with benchmark 0.0012655172413793547
# Test accuracy is 0.9993758620689656
# diff with benchmark -4.482758620683036e-05
# Test accuracy is 0.999551724137931
# diff with benchmark 0.004427586206896539
# Test accuracy is 0.9995620689655172
# diff with benchmark 9.655172413791657e-05
# Test accuracy is 0.9994724137931035
# diff with benchmark 0.009989655172413792
# Test accuracy is 0.9996586206896552
# diff with benchmark 0.01047931034482763
# Test accuracy is 1.0
# diff with benchmark 0.002051724137931088
# Test accuracy is 0.9996344827586207
# diff with benchmark -2.7586206896579313e-05
# Test accuracy is 0.9998344827586206
# diff with benchmark 0.02232068965517231
# Test accuracy is 0.9998448275862069
# diff with benchmark 0.002034482758620615
# Test accuracy is 0.9998310344827587
# diff with benchmark 0.0016793103448276003
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0024724137931034784
# Test accuracy is 1.0
# diff with benchmark 0.0020068965517241466
# Test accuracy is 0.9998137931034483
# diff with benchmark 0.007724137931034547
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.0013862068965516672
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.00015172413793096418
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.00011379310344827864
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.00034137931034483593
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0034241379310344655
# Test accuracy is 0.9999
# diff with benchmark 0.00012413793103449589
# Test accuracy is 0.999851724137931
# diff with benchmark 0.0003310344827586187
# Test accuracy is 0.9999482758620689
# diff with benchmark 0.002351724137930944
# Test accuracy is 1.0
# diff with benchmark 0.0011103448275862071
# Test accuracy is 1.0
# diff with benchmark 0.0015206896551723803
# Test accuracy is 0.9996241379310344
# diff with benchmark 0.0038172413793102766
# Test accuracy is 0.9994206896551724
# diff with benchmark 0.0032655172413792455
# Test accuracy is 0.9993413793103448
# diff with benchmark 0.019399999999999973
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.001634482758620659
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.0
# Test accuracy is 0.9992379310344828
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 1.0
# diff with benchmark 0.0017000000000000348
# Test accuracy is 1.0
# diff with benchmark 0.002017241379310364
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.0013793103448275223
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0010965517241379175
# Test accuracy is 0.9988724137931034
# diff with benchmark 6.896551724144828e-06
# Test accuracy is 0.999951724137931
# diff with benchmark 0.0026999999999999247
# Test accuracy is 0.9999758620689655
# diff with benchmark 0.03803448275862065
# Test accuracy is 1.0
# diff with benchmark 0.0011034482758620623
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.0
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0012068965517241237
# Test accuracy is 0.9993413793103448
# diff with benchmark -7.241379310340967e-05
# Test accuracy is 1.0
# diff with benchmark 0.0007965517241379505
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.0018793103448275783
# Test accuracy is 1.0
# diff with benchmark 0.002768965517241373
# Test accuracy is 0.999203448275862
# diff with benchmark 0.013917241379310274
# Test accuracy is 0.9998793103448276
# diff with benchmark 0.0009034482758620843
# Test accuracy is 0.9998413793103448
# diff with benchmark 0.002575862068965429
# Test accuracy is 0.9999310344827587
# diff with benchmark 0.0012448275862069202
# Test accuracy is 0.9993689655172414
# diff with benchmark 0.0006862068965517443
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0
# Test accuracy is 0.9999103448275862
# diff with benchmark 0.004751724137931013
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.010844827586206973
# Test accuracy is 0.9999344827586207
# diff with benchmark 0.00013793103448278554
# Test accuracy is 0.9999724137931034
# diff with benchmark 9.310344827584416e-05
# Test accuracy is 1.0
# diff with benchmark 0.0024655172413793336
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.009499999999999953
# Test accuracy is 0.9996724137931035
# diff with benchmark 0.005365517241379347
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.0012068965517241237
# Test accuracy is 0.9989413793103449
# diff with benchmark 0.0008793103448276884
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.0027000000000000357
# Test accuracy is 0.9996620689655172
# diff with benchmark 3.448275862072414e-05
# Test accuracy is 0.9995068965517241
# diff with benchmark 0.001117241379310241
# Test accuracy is 0.9996034482758621
# diff with benchmark 0.0007344827586207581
# Test accuracy is 0.999951724137931
# diff with benchmark 0.0018827586206896507
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0014655172413793327
# Test accuracy is 0.9995310344827586
# diff with benchmark 0.005872413793103437
# Test accuracy is 0.9998448275862069
# diff with benchmark 0.00019999999999997797
# Test accuracy is 0.9998551724137931
# diff with benchmark 0.0008586206896551429
# Test accuracy is 1.0
# diff with benchmark 0.0034172413793103207
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.001775862068965517
# Test accuracy is 1.0
# diff with benchmark 0.005251724137931069
# Test accuracy is 0.9996793103448276
# diff with benchmark 0.0008586206896551429
# Test accuracy is 0.9996655172413793
# diff with benchmark 0.0016241379310344417
# Test accuracy is 0.9998586206896551
# diff with benchmark 0.002627586206896515
# Test accuracy is 0.9997
# diff with benchmark 0.007641379310344809
# Test accuracy is 0.9999724137931034
# diff with benchmark 0.010141379310344756
# Test accuracy is 0.9996413793103448
# diff with benchmark 0.0018379310344827093
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.002151724137931077
# Test accuracy is 0.9999379310344828
# diff with benchmark 0.00813448275862072
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0007034482758621063
# Test accuracy is 1.0
# diff with benchmark 0.002051724137931088
# Test accuracy is 0.9992310344827586
# diff with benchmark 0.0032758620689655737
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.002710344827586253
# Test accuracy is 0.9997103448275863
# diff with benchmark 0.01597931034482758
# Test accuracy is 0.9999103448275862
# diff with benchmark 0.003655172413793095
# Test accuracy is 0.9998310344827587
# diff with benchmark 0.005520689655172495
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.002720689655172359
# Test accuracy is 0.9998758620689655
# diff with benchmark 5.51724137930476e-05
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0012448275862069202
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.004227586206896561
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.011641379310344813
# Test accuracy is 1.0
# diff with benchmark 0.0012068965517241237
# Test accuracy is 1.0
# diff with benchmark 0.001251724137931065
# Test accuracy is 1.0
# diff with benchmark 0.0019379310344828093
# Test accuracy is 0.9999793103448276
# diff with benchmark 0.0
# Test accuracy is 0.9998931034482759
# diff with benchmark 0.034255172413793056
# Test accuracy is 0.9999448275862068
# diff with benchmark 0.012696551724137861
# Test accuracy is 1.0
# diff with benchmark 0.004631034482758589
# Test accuracy is 0.999348275862069
# diff with benchmark 1.3793103448289656e-05
# Test accuracy is 0.9996758620689655
# diff with benchmark 0.02611034482758623
# Test accuracy is 0.9990793103448276
# diff with benchmark 0.006886206896551728
# Test accuracy is 0.9998551724137931
# diff with benchmark -3.448275862072414e-06
# Test accuracy is 0.9993344827586207
# diff with benchmark -3.448275862072414e-06
# Test accuracy is 0.9998310344827587
# diff with benchmark 0.002386206896551779
# Test accuracy is 0.9993413793103448
# diff with benchmark 0.01049310344827592
# Test accuracy is 1.0
# diff with benchmark 0.0007655172413792988
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.00013448275862071313
# Test accuracy is 0.9995379310344827
# diff with benchmark 0.006524137931034457
# Test accuracy is 1.0
# diff with benchmark 0.0029655172413792785
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.0
# Test accuracy is 0.9996103448275863
# diff with benchmark 0.013862068965517338
# Test accuracy is 0.9999275862068966
# diff with benchmark 0.0
# Test accuracy is 0.9994758620689655
# diff with benchmark 0.0023000000000000798
# Test accuracy is 1.0
# diff with benchmark 0.0016586206896551658
# Test accuracy is 0.999496551724138
# diff with benchmark 0.005813793103448317
# Test accuracy is 0.9999448275862068
# diff with benchmark 0.0013206896551724023
# Test accuracy is 0.9993827586206897
# diff with benchmark 0.0
# Test accuracy is 0.9999275862068966
# diff with benchmark 0.0
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.014934482758620637
# Test accuracy is 0.9998344827586206
# diff with benchmark -6.896551724144828e-06
# Test accuracy is 1.0
# diff with benchmark 0.0035586206896551786
# Test accuracy is 0.999951724137931
# diff with benchmark 0.0030827586206896296
# Test accuracy is 0.9999758620689655
# diff with benchmark 0.0005999999999999339
# Test accuracy is 0.9996758620689655
# diff with benchmark 0.0
# Test accuracy is 0.9998241379310345
# diff with benchmark 0.0028551724137931833
# Test accuracy is 0.9998931034482759
# diff with benchmark 0.0001517241379310752
# Test accuracy is 0.9997241379310344
# diff with benchmark 0.0036068965517240814
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.016844827586206867
# Test accuracy is 0.9999448275862068
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0014448275862068982
# Test accuracy is 1.0
# diff with benchmark 0.0026310344827585874
# Test accuracy is 0.9994586206896552
# diff with benchmark 0.0
# Test accuracy is 0.9997896551724138
# diff with benchmark 0.0035586206896551786
# Test accuracy is 0.9998620689655172
# diff with benchmark 0.001951724137930988
# Test accuracy is 1.0
# diff with benchmark 0.0033655172413793455
# Test accuracy is 0.9999551724137931
# diff with benchmark 0.007017241379310257
# Test accuracy is 0.9995206896551724
# diff with benchmark 0.00025172413793095316
# Test accuracy is 0.9986103448275863
# diff with benchmark 0.033834482758620776
# Test accuracy is 0.9992689655172414
# diff with benchmark 0.0021206896551724252
# Test accuracy is 0.9998862068965517
# diff with benchmark 0.0009965517241379285
# Test accuracy is 0.9994379310344828
# diff with benchmark -6.551724137926485e-05
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.003044827586206833
# Test accuracy is 0.9997103448275863
# diff with benchmark 0.003996551724137931
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0030068965517241475
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.01398275862068965
# Test accuracy is 1.0
# diff with benchmark 0.0037586206896551566
# Test accuracy is 0.9999448275862068
# diff with benchmark 0.0009517241379309871
# Test accuracy is 0.9998413793103448
# diff with benchmark 0.0012034482758620513
# Test accuracy is 0.9996827586206897
# diff with benchmark 0.010513793103448243
# Test accuracy is 0.9996310344827586
# diff with benchmark 0.009262068965517178
# Test accuracy is 0.9998068965517242
# diff with benchmark 3.448275862072414e-06
# Test accuracy is 0.9999896551724138
# diff with benchmark 0.0013620689655172713
# Test accuracy is 0.9999931034482759
# diff with benchmark 0.0011896551724137616
# Test accuracy is 0.999951724137931
# diff with benchmark 0.004479310344827514
# Test accuracy is 1.0
# diff with benchmark 0.0017724137931034445
# Test accuracy is 0.9997827586206897
# diff with benchmark 0.0024551724137931163
# Test accuracy is 1.0
# diff with benchmark 0.002720689655172359
# Test accuracy is 0.9992275862068966
# diff with benchmark -2.7586206896579313e-05
# Test accuracy is 1.0
# diff with benchmark 0.0021413793103448597
# Test accuracy is 1.0
# diff with benchmark 0.0018620689655172162
# Test accuracy is 1.0
# diff with benchmark 0.001727586206896503
# Test accuracy is 1.0
# diff with benchmark 0.0008827586206896498
# Test accuracy is 0.9997793103448276
# diff with benchmark -3.103448275865173e-05
# Test accuracy is 0.9998068965517242
# diff with benchmark 0.013541379310344825
# Test accuracy is 1.0
# diff with benchmark 0.0034448275862069
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.00602068965517244
# Test accuracy is 0.9999275862068966
# diff with benchmark 0.0032586206896552117
# Test accuracy is 1.0
# diff with benchmark 0.0022551724137931384
# Test accuracy is 0.9999620689655172
# diff with benchmark 0.0011999999999999789
# Test accuracy is 0.9999758620689655
# diff with benchmark 0.0017034482758619962
# Test accuracy is 0.9996793103448276
# diff with benchmark 0.01363448275862067
# Test accuracy is 0.9997620689655172
# diff with benchmark -1.724137931036207e-05
# Test accuracy is 1.0
# diff with benchmark 0.0024137931034482474
# Test accuracy is 0.9979310344827587
# diff with benchmark 0.037800000000000056
# Test accuracy is 1.0
# diff with benchmark 0.006203448275862056
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0015310344827585975
# Test accuracy is 0.9999275862068966
# diff with benchmark 0.002168965517241439
# Test accuracy is 0.9999862068965517
# diff with benchmark 0.0005689655172413932
# Test accuracy is 0.9999689655172413
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0015793103448276113
# Test accuracy is 0.9995413793103448
# diff with benchmark 0.03201724137931028
# Test accuracy is 0.9994068965517241
# diff with benchmark 0.0041827586206896195
# Test accuracy is 0.9999620689655172
# diff with benchmark 0.0032551724137930282
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0
# Test accuracy is 0.9993724137931035
# diff with benchmark 0.0027586206896551557
# Test accuracy is 1.0
# diff with benchmark 0.004393103448275815
# Test accuracy is 0.9994586206896552
# diff with benchmark 0.00022758620689655729
# Test accuracy is 1.0
# diff with benchmark 0.0030000000000000027
# Test accuracy is 0.9995206896551724
# diff with benchmark 0.0019413793103447707
# Test accuracy is 1.0
# diff with benchmark 0.001175862068965472
# Test accuracy is 0.9999655172413793
# diff with benchmark 0.0006413793103448029
# Test accuracy is 1.0
# diff with benchmark 0.002168965517241328
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0024137931034482474
# Test accuracy is 1.0
# diff with benchmark 0.0011724137931033995
# Test accuracy is 0.9998689655172414
# diff with benchmark 0.007065517241379271
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9995862068965518
# diff with benchmark 0.002686206896551746
# Test accuracy is 0.9997896551724138
# diff with benchmark 0.0025965517241379743
# Test accuracy is 0.9993275862068965
# diff with benchmark 0.004768965517241375
# Test accuracy is 0.9999310344827587
# diff with benchmark 0.0
# Test accuracy is 0.9997758620689655
# diff with benchmark 0.011551724137931041
# Test accuracy is 0.9996034482758621
# diff with benchmark 0.005351724137931058
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.0012275862068965582
# Test accuracy is 0.9999965517241379
# diff with benchmark 0.002734482758620649
# Test accuracy is 1.0
# diff with benchmark 0.000993103448275856
# Test accuracy is 0.9998137931034483
# diff with benchmark 0.001134482758620714
# Test accuracy is 0.9992310344827586
# diff with benchmark 0.0
# Test accuracy is 0.9999413793103449
# diff with benchmark 0.0
# Test accuracy is 0.9994551724137931
# diff with benchmark 0.0018206896551724583
# Test accuracy is 0.9999034482758621
# diff with benchmark 0.005865517241379292
# Test accuracy is 1.0
# diff with benchmark 0.004048275862069017
# Test accuracy is 0.9997689655172414
# diff with benchmark -1.0344827586217242e-05
# Test accuracy is 0.9981862068965517
# diff with benchmark 4.482758620683036e-05
# Test accuracy is 0.9999758620689655
# diff with benchmark 0.0012034482758620513
# Test accuracy is 0.9998724137931034
# diff with benchmark 0.005886206896551727
# Test accuracy is 0.9998793103448276
# diff with benchmark 0.004565517241379324
# Test accuracy is 1.0
# diff with benchmark 0.0021241379310344977
# Test accuracy is 0.9995724137931035
# diff with benchmark 0.0041827586206896195
# Test accuracy is 0.9998034482758621
# diff with benchmark 0.0034344827586206828
# Test accuracy is 0.9994793103448276
# diff with benchmark 0.00507931034482767
# Test accuracy is 0.999403448275862
# diff with benchmark 8.275862068962692e-05
# Test accuracy is 0.9990965517241379
# diff with benchmark -6.896551724144828e-06
# Test accuracy is 0.9994379310344828
# diff with benchmark 0.0007689655172413712
# Test accuracy is 0.9999827586206896
# diff with benchmark 0.002927586206896482
# Test accuracy is 0.9999482758620689
# diff with benchmark 7.586206896548209e-05
# Test accuracy is 0.9979068965517242
# diff with benchmark 0.013841379310344792
# Test accuracy is 0.9996034482758621
# diff with benchmark 0.0034413793103448276
# Test accuracy is 0.9991724137931034
# diff with benchmark 0.003044827586206833
# Test accuracy is 0.9998172413793104
# diff with benchmark 0.0009896551724137836
# Test accuracy is 0.999203448275862
# diff with benchmark 0.026672413793103478
# Test accuracy is 0.9996758620689655
# diff with benchmark 0.004693103448275893
# Test accuracy is 0.9997758620689655
# diff with benchmark 0.013896551724137951
# Test accuracy is 0.9997
# diff with benchmark 0.0024793103448276232

# %%
dFRes2["learn_rate(%)"].describe()
# Out:
# count    451.000000
# mean       0.398618
# std        0.792060
# min       -0.009325
# 25%        0.069553
# 50%        0.193146
# 75%        0.385278
# max        8.940756
# Name: learn_rate(%), dtype: float64

# %%
dFRes2["accuracy"].describe()
# Out:
# count    451.000000
# mean       0.999770
# std        0.000501
# min        0.993652
# 25%        0.999717
# 50%        0.999938
# 75%        0.999997
# max        1.000000
# Name: accuracy, dtype: float64

# %%
dFRes2["AUC"].describe()
# Out:
# count    451.000000
# mean       0.890588
# std        0.189644
# min        0.001000
# 25%        0.909658
# 50%        0.989633
# 75%        0.999997
# max        1.000000
# Name: AUC, dtype: float64

# %%
dFRes2.sample(100).head(15)
# Out:
#                tags  accuracy  benchmark       AUC  learn_rate(%)
# 264             kol  0.999841   0.997266  0.979799       0.258293
# 235  es kelapa muda  0.999993   0.999652  0.995048       0.034150
# 251      nasi rames  0.999993   0.998897  0.998436       0.109776
# 180           rawon  1.000000   0.998414  1.000000       0.158873
# 4           bintang  0.999979   0.997490  0.998619       0.249592
# 443            sate  0.997907   0.984066  0.956782       1.406551
# 12        teh pucuk  1.000000   0.999145  1.000000       0.085590
# 55           piatos  0.999969   0.999969  0.500000       0.000000
# 209        makaroni  0.999745   0.996855  0.964348       0.289877
# 225           molto  0.999634   0.999662  0.510187      -0.002760
# 115           bubur  0.999345   0.991003  0.976691       0.841710
# 226     ayam goreng  0.999834   0.977514  0.998567       2.283414
# 240           motor  1.000000   0.998890  1.000000       0.111158
# 229       krim pagi  0.999993   0.997521  0.999997       0.247856
# 440           molen  0.999438   0.998669  0.822494       0.076999

# %%
(dFRes2.AUC>0.8).mean()*451
# Out:
# 364.0

# %%
((dFRes2.AUC>0.8)&(dFRes2["learn_rate(%)"]>0)).mean()*451
# Out:
# 364.0

# %%
dFRes2[(dFRes2.AUC>0.8)&(dFRes2["learn_rate(%)"]>0)][["accuracy","AUC"]].describe()
# Out:
#          accuracy         AUC
# count  364.000000  364.000000
# mean     0.999794    0.977750
# std      0.000524    0.038582
# min      0.993652    0.807052
# 25%      0.999785    0.972510
# 50%      0.999962    0.995135
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
# 364, 0.9777, 0.9997
# All, 0.8905, 0.9997

# %%
good_tags=', '.join(dFRes2[(dFRes2.AUC>0.8)&(dFRes2["learn_rate(%)"]>0)].tags.tolist())

# %%
ss=open(model_path+"good_tags_dectree.txt",'w')
ss.write(good_tags)
ss.close()
