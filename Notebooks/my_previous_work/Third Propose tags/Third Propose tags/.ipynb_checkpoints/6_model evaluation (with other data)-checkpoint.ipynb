# %%
# %matplotlib inline
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # Get The Data Test

# %%
data_path='../../data/'
data_raw_path="../../data/raw/for third propose/"
data_man_path="../../data/manipulate/for third propose/"
model_path="../../model/modeling_third_propose/"

# %%
dtesting=pd.read_csv(data_man_path+"data_test_gocommerce_items_cln.csv")
dtag=pd.read_csv(data_man_path+"data_tag_goshop3_unique.csv").drop_duplicates()
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# dtesting

# %%
dtesting2=dtesting[~(dtesting.item_list_cln1.isnull())]
dtesting2=dtesting2[~(dtesting2.item_list_cln2.isnull())]

# %% [markdown]
# # Label with real (rule based)

# %%
dtag["num_word"]=dtag.Keywords.apply(lambda x : len(x.split(" ")))
dtag["num_word_tag"]=dtag.Tags.apply(lambda x : len(x.split(" ")))

keyword_set=set(dtag.Keywords.unique())
keyword_set1=set([t for t in keyword_set if len(t.split(" "))==1])
keyword_set2=set([t for t in keyword_set if len(t.split(" "))==2])
keyword_set3=set([t for t in keyword_set if len(t.split(" "))==3])


ts=set(dtag.Tags.unique())
ts1=set([t for t in ts if len(t.split(" "))==1])
ts2=set([t for t in ts if len(t.split(" "))==2])
ts3=set([t for t in ts if len(t.split(" "))==3])

dict_keyword=pd.DataFrame(dtag.Tags)
dict_keyword.index=dtag.Keywords
dict_keyword=dict_keyword["Tags"].to_dict()

# %%
def include_tags(X,Y):
    X2=[]
    for x1 in X:
        k=0
        for y1 in Y:
            if x1 in y1:
                k=1
                break
        if k==0:
            X2.append(x1)
    
    return set(X2)|Y

def remove_term(text,X):
    for term in X:
        text=text.replace(' '+term+' '," ")
        text=re.sub( '\s+', ' ',text)
    return text
    

def tags(tx):
    X3=set([tg for tg in keyword_set3 if ' '+tg+' ' in ' '+tx+' '])
    tx2=remove_term(' '+tx+' ',X3)
    X3=set([dict_keyword[t] for t in X3])
    
    X2=set([tg for tg in keyword_set2 if ' '+tg+' ' in ' '+tx2+' '])
    tx3=remove_term(' '+tx2+' ',X2)
    X2=set([dict_keyword[t] for t in X2])

    X1=keyword_set1&set(tx3.split(" "))
    X1=set([dict_keyword[t] for t in X1])
    
    X_tags0=X1|X2|X3
    
    T1=set([t for t in X_tags0 if len(t.split(" "))==1])
    T2=set([t for t in X_tags0 if len(t.split(" "))==2])
    T3=set([t for t in X_tags0 if len(t.split(" "))==3])
    
    T12=include_tags(T1,T2)
    X_tags=include_tags(T12,T3)
    
    return X_tags

def tags_mult(X):
    XX=X.split(",")
    tg_X=set([])
    for t in XX:
        if len(t)>=3:
            t2=t.strip()
            tg_X=tg_X|tags(t2)
            
    return tuple(tg_X)

# %%
dtesting2["real_tags"]=dtesting2.item_list_cln1.apply(tags_mult)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-212a7402d56b> in <module>()
# ----> 1 dtesting2["real_tags"]=dtesting2.item_list_cln1.apply(tags_mult)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-69f7c66e084a> in tags_mult(X)
#      48         if len(t)>=3:
#      49             t2=t.strip()
# ---> 50             tg_X=tg_X|tags(t2)
#      51
#      52     return tuple(tg_X)
#
# <ipython-input-7-69f7c66e084a> in tags(tx)
# ...

# %%
X=dtesting2.item_list_cln2

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from imblearn.over_sampling import RandomOverSampler,SMOTE
from sklearn.metrics import hamming_loss
from sklearn.preprocessing import LabelEncoder
from skmultilearn.problem_transform import LabelPowerset,ClassifierChain
from skmultilearn.adapt import MLkNN
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from gensim.models import Word2Vec
from gensim.models.wrappers import FastText
from gensim.models import KeyedVectors
from collections import defaultdict
from sklearn.preprocessing import RobustScaler
from sklearn.externals import joblib

# %% [markdown]
# # DL1 Model

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
multilabel_binarizer_DL1=joblib.load(model_path+"multilabel_bin_for_DL1.pkl")
tokenizer_DL1=joblib.load(model_path+"tokenizer_for_DL1.pkl")

# %%
## Transform
# sequence encode
encoded_docs = tokenizer_DL1.texts_to_sequences(X)
# pad sequences
max_length = 50
X2_DL1 = pad_sequences(encoded_docs, maxlen=max_length, padding='post')

# %%
# load json and create model
json_file = open(model_path+"wv_DL.json", 'r')
loaded_model_json = json_file.read()
json_file.close()
DL1_model = model_from_json(loaded_model_json)
# load weights into new model
DL1_model.load_weights(model_path+"wv_DL.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
DL1_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Loaded model from disk

# %%
y_pred_DL1 = DL1_model.predict(X2_DL1) #Benchmark 0.16

# %%
def transform_y(yp,a=0.22):
    YY=(yp>a).astype(int)
    while YY.sum()==0 and a>=0.34:
        a=a-0.02
        YY=(yp>a).astype(int)
    return YY

# %%
y_pred2_DL1=np.array([transform_y(yp,a=0.53) for yp in y_pred_DL1])
dtesting2["pred_tag_DL1"]=multilabel_binarizer_DL1.inverse_transform(y_pred2_DL1)

# %%
gt_dl1=open(model_path+"good_tags_DL1.txt",'r')
gt_DL1=gt_dl1.readline().split(", ")

# %%
len(gt_DL1)
# Out:
# 584

# %% [markdown]
# # DL2 Model

# %%
multilabel_binarizer_DL2=joblib.load(model_path+"multilabel_bin_for_DL2.pkl")
tokenizer_DL2=joblib.load(model_path+"tokenizer_for_DL2.pkl")

# %%
## Transform
# sequence encode
encoded_docs_DL2 = tokenizer_DL2.texts_to_sequences(X)
# pad sequences
max_length = 80
X2_DL2 = pad_sequences(encoded_docs_DL2, maxlen=max_length, padding='post')

# %%
# load json and create model
json_file = open(model_path+"wv_DL2.json", 'r')
loaded_model_json = json_file.read()
json_file.close()
DL2_model = model_from_json(loaded_model_json)
# load weights into new model
DL2_model.load_weights(model_path+"wv_DL2.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
DL2_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Loaded model from disk

# %%
y_pred_DL2 = DL2_model.predict(X2_DL2) #Benchmark 0.16

# %%
def transform_y(yp,a=0.22):
    YY=(yp>a).astype(int)
    while YY.sum()==0 and a>=0.35:
        a=a-0.02
        YY=(yp>a).astype(int)
    return YY

# %%
y_pred2_DL2=np.array([transform_y(yp,a=0.55) for yp in y_pred_DL2])
dtesting2["pred_tag_DL2"]=multilabel_binarizer_DL2.inverse_transform(y_pred2_DL2)

# %%
## Num Tags,    AUC,      Acc
#       361, 0.9442,   0.9986
#       All, 0.8895,   0.9988

# %%
gt_dl2=open(model_path+"good_tags_DL2.txt",'r')
gt_DL2=gt_dl2.readline().split(", ")

# %%
len(gt_DL2)
# Out:
# 619

# %%
# dtesting2.to_csv(data_man_path+"model_result_on_data_testing1.csv",index=False)
import ast
dtesting2=pd.read_csv(data_man_path+"model_result_on_data_testing1.csv")
dtesting2["real_tags"]=dtesting2.real_tags.apply(lambda x : set(ast.literal_eval(x)))
dtesting2["pred_tag_DL1"]=dtesting2.pred_tag_DL1.apply(lambda x : set(ast.literal_eval(x)))
dtesting2["pred_tag_DL2"]=dtesting2.pred_tag_DL2.apply(lambda x : set(ast.literal_eval(x)))
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Evaluation

# %%
dtesting2[["item_list","real_tags","pred_tag_DL1","pred_tag_DL2"]].sample(15)
# Out:
#                                                 item_list  \
# 688766  case blueray galaxy hologram (udah dipesenin k...
# 487991                                             parsel
# 901542                                                Kue
# 67884             hazelnut chocolate milk tea (l),pudding
# 838578                 sempol sama bakso masing2 20 tusuk
# 785554   bioplacenton,kenalog,actifed expectorant  120 ml
# 88038             vanilla latte venti,thai cold brew tall
# 650365  Tongkat pramuka 2x warna merah putihHubungi no...
# 973607                              note book asian games
# 715151  nanas madu kupas,indofood bumbu instan kare 45 gr
# 2070       nastetenyet,paket dada daging (bakar / goreng)
# 609965  toko jamu seberang pasar kemuning beli obat be...
# 833351                                kertas kado besar 8
# 922420  setia kopi arabica toraja 250 gr,ellen kopi ar...
# 421908                                   sayuran dan ikan
#
# ...

# %%
dSAMPLE0=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL1.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL2.apply(lambda x: len(x)==0))][["item_list","real_tags",
                        "pred_tag_DL1",
                        "pred_tag_DL2"]].sample(3)

dSAMPLE1=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)>0))
                      &(dtesting2.pred_tag_DL1.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL2.apply(lambda x: len(x)==0))][["item_list","real_tags",
                        "pred_tag_DL1",
                        "pred_tag_DL2"]].sample(3)

dSAMPLE2=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL1.apply(lambda x: len(x)>0))
                      &(dtesting2.pred_tag_DL2.apply(lambda x: len(x)==0))][["item_list","real_tags",
                        "pred_tag_DL1",
                        "pred_tag_DL2"]].sample(3)

dSAMPLE3=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL1.apply(lambda x: len(x)==0))
                      &(dtesting2.pred_tag_DL2.apply(lambda x: len(x)>0))][["item_list","real_tags",
                        "pred_tag_DL1",
                        "pred_tag_DL2"]].sample(3)

pd.concat([dSAMPLE0,dSAMPLE1,dSAMPLE2,dSAMPLE3])

# dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))&(dtesting2.item_list.str.contains("jco"))][["item_list","item_list_cln2","real_tags",
# #                         "pred_tag_dectree","pred_tag_DL1",
#                         "pred_tag_DL2"]]
# Out:
#                                                  item_list   real_tags  \
# 685841                                        banana stick          {}
# 498115                                              serbet          {}
# 479359                      isi polaroid instax 8 isi 2x10          {}
# 660996   makroni dadahakering asin pedas 6 bungkus @500...  {makaroni}
# 1017629    asifit, ketemu dengan mbak rahma tadi sdh pesan    {asifit}
# 228674                   monica lapis legit special 1 2 kg    {monica}
# 127503                paket geprek bensu,tahu geprek bensu          {}
# 1014774  pas di samping Gg. jambi pets shop kucing beli...          {}
# 753004                        triaminic  exp pilek   60 ml          {}
# 272464   rudy hadisuwarno hair spray non aerosol super ...          {}
# 654528                                            es teler          {}
# 886322   mediklin tr ungu 5 pcs /// dan betametason sal...          {}
#
#           pred_tag_DL1 pred_tag_DL2
# ...

# %%
## portion of zero real tags
dtesting3_0=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)>0))]
len(dtesting3_0)/float(len(dtesting2))
# Out:
# 0.8126419779426401

# %%
## Covered zero real tags
dtesting_zero_real=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))]
dtesting3_1=dtesting2[(dtesting2.real_tags.apply(lambda x: len(x)==0))&((
    (dtesting2.pred_tag_DL1.apply(lambda x: len(x)>0))|
        (dtesting2.pred_tag_DL2.apply(lambda x: len(x)>0))))]

len(dtesting3_1)/float(len(dtesting_zero_real))
# Out:
# 0.14311641171895256

# %%
dtesting_zero_real["is_exist_pred_DL1"]=dtesting_zero_real.pred_tag_DL1.apply(lambda x: len(x)>0)
dtesting_zero_real["is_exist_pred_DL2"]=dtesting_zero_real.pred_tag_DL2.apply(lambda x: len(x)>0)
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
(dtesting_zero_real[["is_exist_pred_DL1",
                    "is_exist_pred_DL2"]].sum()/float(len(dtesting_zero_real)))
# Out:
# is_exist_pred_DL1    0.088497
# is_exist_pred_DL2    0.093560
# dtype: float64

# %%
len(dtag)
# Out:
# 1733

# %%
def check_tag2(list_X,i):
    if i in list_X:
        return 1
    else :
        return 0
    
def tags_eval(test2,tag_pred):
    acc=[]
    benc=[]
    lrate=[]
    auc_list=[]
    for category in list(ts):
        # compute the testing accuracy
        True_tag=test2.real_tags.apply(lambda x: check_tag2(x,category)).as_matrix()
        Pred_tag=test2[tag_pred].apply(lambda x: check_tag2(x,category)).as_matrix()

        acc_score=accuracy_score(True_tag,Pred_tag)
        try:
            auc_cat=roc_auc_score(True_tag,Pred_tag)
        except:
            auc_cat=0.001

        print('Test accuracy is {}'.format(acc_score))
        if True_tag.mean()<0.5:
            benchm=1-True_tag.mean()
        else:
            benchm=True_tag.mean()
        print('diff with benchmark {}'.format(acc_score-benchm))

        acc.append(acc_score)
        benc.append(benchm)
        lrate.append(((acc_score-benchm)/float(benchm))*100)
        auc_list.append(auc_cat)

    dFRes2=pd.DataFrame({"tags":list(ts),"accuracy":acc,"benchmark":benc,"AUC":auc_list,"learn_rate(%)":lrate})
    return dFRes2

# %%
from sklearn.metrics import accuracy_score,roc_auc_score

# %% [markdown]
# #### DL1

# %%
test_DL1=dtesting3_0[["item_list_cln2","real_tags","pred_tag_DL1"]]

# %%
# for c in ts:
#     cek_tag=test_DL1.real_tags.apply(lambda x : check_tag2(x,c))
#     test_DL1[c]=cek_tag

# %%
dd_eval_DL1=tags_eval(test_DL1,"pred_tag_DL1")
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.9994643644103555
# diff with benchmark 0.0019093006029123893
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.9997562096222187
# diff with benchmark 4.571069583403364e-05
# ...

# %%
((dd_eval_DL1.AUC>0.8)&(dd_eval_DL1["learn_rate(%)"]>0)).mean()*451
# Out:
# 233.43605150214594

# %%
dd_eval_DL1[(dd_eval_DL1.AUC>0.8)&(dd_eval_DL1["learn_rate(%)"]>0)][["accuracy","AUC"]].describe()
# Out:
#          accuracy         AUC
# count  603.000000  603.000000
# mean     0.999281    0.891299
# std      0.001050    0.051554
# min      0.986672    0.800051
# 25%      0.999152    0.847393
# 50%      0.999601    0.892678
# 75%      0.999804    0.935024
# max      1.000000    1.000000

# %% [markdown]
# #### DL2

# %%
test_DL2=dtesting3_0[["item_list_cln2","real_tags","pred_tag_DL2"]]

# %%
# for c in ts:
#     cek_tag=test_DL2.real_tags.apply(lambda x : check_tag2(x,c))
#     test_DL2[c]=cek_tag

# %%
dd_eval_DL2=tags_eval(test_DL2,"pred_tag_DL2")
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.9995077309679415
# diff with benchmark 0.0009657849581337086
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.9994784292398429
# diff with benchmark 0.008102513853857074
# ...

# %%
((dd_eval_DL2.AUC>0.8)&(dd_eval_DL2["learn_rate(%)"]>0)).mean()*451
# Out:
# 252.40515021459225

# %%
dd_eval_DL2[(dd_eval_DL2.AUC>0.8)&(dd_eval_DL2["learn_rate(%)"]>0)][["accuracy","AUC"]].describe()
# Out:
#          accuracy         AUC
# count  652.000000  652.000000
# mean     0.999401    0.895786
# std      0.000837    0.051804
# min      0.988536    0.800310
# 25%      0.999278    0.852051
# 50%      0.999652    0.896151
# 75%      0.999819    0.939440
# max      0.999993    0.998650

# %%
good_tags=', '.join(dd_eval_DL2[(dd_eval_DL2.AUC>0.8)&(dd_eval_DL2["learn_rate(%)"]>0)].tags.tolist())
ss=open(model_path+"good_tags_DL2_from_test.txt",'w')
ss.write(good_tags)
ss.close()

# %%
dtesting2.head()
# Out:
#                  booking_time     order_no payment_method_name  \
# 0  2018-09-30 01:00:58.129129  F-103656423                FREE
# 1  2018-09-16 04:44:07.947744   F-94443846           PAY_LATER
# 2  2018-05-11 05:39:01.530242   F-14238997                FREE
# 3  2018-09-24 11:40:54.184264  F-100085239           PAY_LATER
# 4  2018-09-19 11:00:09.280537   F-96640563           PAY_LATER
#
#                    merchant_name  type  \
# 0               Soto Cemorojajar  food
# 1      Warung Sate Solo Pak Hadi  food
# 2                         HokBen  food
# 3  Shukufuku Japanese StreetFood  food
# 4                    Ayam Santai  food
#
#                                          item_list  \
# 0                                          mendoan
# 1                          sate ayam,tongseng ayam
# 2                                     hoka hemat 1
# 3                                         gyu zuke
# 4  paket ayam geprek nasi putih sambal korek pedas
#
# ...

# %%
dtesting2_upload=dtesting2[["order_no","merchant_name","type","item_list","real_tags","pred_tag_DL1","pred_tag_DL2"]]

# %%
dtesting2_upload["real_tags"]=dtesting2_upload["real_tags"].apply(lambda x:', '.join(x))
dtesting2_upload["pred_tag_DL1"]=dtesting2_upload["pred_tag_DL1"].apply(lambda x:', '.join(x))
dtesting2_upload["pred_tag_DL2"]=dtesting2_upload["pred_tag_DL2"].apply(lambda x:', '.join(x))
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dtesting2_upload.to_csv(data_man_path+"model_result_on_data_testing1_upload.csv",sep=";")

# %%
dtesting2_upload.head()
# Out:
#       order_no                  merchant_name  type  \
# 0  F-103656423               Soto Cemorojajar  food
# 1   F-94443846      Warung Sate Solo Pak Hadi  food
# 2   F-14238997                         HokBen  food
# 3  F-100085239  Shukufuku Japanese StreetFood  food
# 4   F-96640563                    Ayam Santai  food
#
#                                          item_list  \
# 0                                          mendoan
# 1                          sate ayam,tongseng ayam
# 2                                     hoka hemat 1
# 3                                         gyu zuke
# 4  paket ayam geprek nasi putih sambal korek pedas
#
#                         real_tags                    pred_tag_DL1  \
# 0
# 1       tongseng, ayam, sate ayam       ayam, sate ayam, tongseng
# 2
# 3
# 4  korek, ayam geprek, nasi putih  ayam geprek, korek, nasi putih
#
#                      pred_tag_DL2
# 0
# 1       ayam, sate ayam, tongseng
# 2
# 3
# 4  ayam geprek, korek, nasi putih
