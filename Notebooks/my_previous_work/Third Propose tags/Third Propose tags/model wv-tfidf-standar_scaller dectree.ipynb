# %% [markdown]
# # Modelling with word embedding

# %%
# https://towardsdatascience.com/multi-label-text-classification-with-scikit-learn-30714b7819c5
# https://docs.google.com/spreadsheets/d/1hg4KKKdivoh6mG7Bena0jYdJSvzgABlWLrU0NX_vHTQ/edit#gid=49385392

# %%
data_path='../../data/'
data_raw_path="../../data/raw/for second propose/"
data_man_path="../../data/manipulate/for second propose/"
model_path="../../model/modeling_second_propose/"

# %%
# %matplotlib inline
import re
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
# from nltk.corpus import stopwords
# stop_words = set(stopwords.words('english'))
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from sklearn.linear_model import SGDClassifier
import seaborn as sns
import nltk
from string import digits
import ast
import itertools

# %%
stop_words=open(data_path+"stopwords_id.txt")
stop_words=set([i[:-1] for i in stop_words.readlines()])

# %% [markdown]
# # Get The Data

# %%
dtag=pd.read_csv(data_man_path+"data_tag_goshop2.csv").drop_duplicates()
# dtag.to_csv(data_man_path+"data_tag_goshop2.csv",index=False)

# %%
dtext2=pd.read_csv(data_man_path+"data_raw_path_w_label2.csv")
dtext2["real_tags"]=dtext2.real_tags.apply(lambda x : set(ast.literal_eval(x)))

# %%
dtext2["num_tags"]=dtext2.real_tags.apply(lambda x: len(x))

# %%
dtag["num_word"]=dtag.Keywords.apply(lambda x : len(x.split(" ")))
dtag["num_word_tag"]=dtag.Tags.apply(lambda x : len(x.split(" ")))

# %%
keyword_set=set(dtag.Keywords.unique())
keyword_set1=set([t for t in keyword_set if len(t.split(" "))==1])
keyword_set2=set([t for t in keyword_set if len(t.split(" "))==2])
keyword_set3=set([t for t in keyword_set if len(t.split(" "))==3])


ts=set(dtag.Tags.unique())
ts1=set([t for t in ts if len(t.split(" "))==1])
ts2=set([t for t in ts if len(t.split(" "))==2])
ts3=set([t for t in ts if len(t.split(" "))==3])

# %%
dict_keyword=pd.DataFrame(dtag.Tags)
dict_keyword.index=dtag.Keywords
dict_keyword=dict_keyword["Tags"].to_dict()

dict_sc=pd.DataFrame(dtag["Sub-Categories"])
dict_sc.index=dtag.Tags
dict_sc=dict_sc["Sub-Categories"].to_dict()

# %%
print(len(ts1),len(ts2))
# Out:
# 267 166

# %%
dtext2.sample(100).head(20)
# Out:
#                 booking_time   order_no  voucher_id  \
# 453659   2018-06-03 09:59:42  478202201         NaN
# 1035042  2018-06-11 04:47:07  478702020         NaN
# 1495967  2018-03-20 10:44:52  460178344         NaN
# 55408    2018-03-21 18:47:58  460881374         NaN
# 1329262  2018-03-16 04:59:25  457717760         NaN
# 1248100  2017-09-18 02:08:10  364716946         NaN
# 924181   2016-08-19 03:48:32  189109555         NaN
# 349637   2018-05-01 04:05:09  476162938         NaN
# 953571   2017-12-10 09:08:54  407024270         NaN
# 1117764  2018-02-23 15:09:28  446427756         NaN
# 784130   2016-11-03 14:00:39  242419500         NaN
# 769648   2017-08-14 03:33:12  351025933         NaN
# 1042152  2018-01-07 06:46:03  422570556         NaN
# 376465   2017-08-05 05:07:19  347760596         NaN
# 448420   2017-09-11 00:01:35  361889677         NaN
# 1166113  2018-08-26 11:14:06  483457900         NaN
# 1309996  2017-11-10 08:40:21  391058107         NaN
# 954800   2017-11-11 13:47:18  391904912         NaN
# 12228    2018-01-10 19:14:27  424364610         NaN
# 1348097  2018-04-17 15:42:03  472432024         NaN
#
#                                                  item_list  \
# 453659                liquid cloud niners rasa mango 2buah
# 1035042         ratjikan xanthone original  500 ml (putih)
# 1495967                                        Buket bunga
# 55408                         anggur merah mcdonald dingin
# 1329262                                             makeup
# 1248100                              rasa choco cheese = 1
# 924181                                   5bakso ,2es teler
# 349637     mie ayam bakso 8 porsi dan pangsit kuah 2 porsi
# 953571                           cake coklat dan blueberry
# 1117764                                 Captain Morgan Rum
# 784130   Nasi Goreng Ayam 1 (pedes dikit) Nasi Goreng K...
# 769648                                      nasi ayam 3bks
# 1042152                           Medicated shampoo 100 ml
# 376465           susu kambing goat milk full cream 3 kotak
# 448420                                       pesaman bobby
# 1166113         dendeng balado 1lele goreng balado 1nasi 2
# 1309996               nasi ayam pedes 3 bungkus, kerupuk 2
# 954800                         Nestle Uk 1,5liter 10 botol
# 12228                   nasi bebek goreng 1 + aqua besar 1
# 1348097               susu lactogrow 4 rasa vanila 750gram
#
#         payment_method_name  \
# 453659      PARTIAL_PAYMENT
# 1035042                CASH
# 1495967                CASH
# 55408                  CASH
# 1329262                CASH
# 1248100                CASH
# 924181      PARTIAL_PAYMENT
# 349637      PARTIAL_PAYMENT
# 953571                 CASH
# 1117764     PARTIAL_PAYMENT
# 784130                 CASH
# 769648                 CASH
# 1042152              GO-PAY
# 376465               GO-PAY
# 448420                 CASH
# 1166113                CASH
# 1309996              GO-PAY
# 954800                 CASH
# 12228                  CASH
# 1348097                CASH
#
#                                             item_list_cln1  \
# 453659                 liquid cloud niners rasa mango buah
# 1035042                ratjikan xanthone original ml putih
# 1495967                                        buket bunga
# 55408                         anggur merah mcdonald dingin
# 1329262                                             makeup
# 1248100                                  rasa choco cheese
# 924181                                    bakso , es teler
# 349637             mie ayam bakso porsi,pangsit kuah porsi
# 953571                               cake coklat,blueberry
# 1117764                                 captain morgan rum
# 784130   nasi goreng ayam pedes dikit nasi goreng kambi...
# 769648                                       nasi ayam bks
# 1042152                               medicated shampoo ml
# 376465             susu kambing goat milk full cream kotak
# 448420                                       pesaman bobby
# 1166113             dendeng balado lele goreng balado nasi
# 1309996                   nasi ayam pedes bungkus, kerupuk
# 954800                             nestle uk , liter botol
# 12228                       nasi bebek goreng , aqua besar
# 1348097                    susu lactogrow rasa vanila gram
#
#                                             item_list_cln2  \
# 453659                 liquid cloud niners rasa mango buah
# 1035042                ratjikan xanthone original ml putih
# 1495967                                        buket bunga
# 55408                         anggur merah mcdonald dingin
# 1329262                                             makeup
# 1248100                                  rasa choco cheese
# 924181                                      bakso es teler
# 349637             mie ayam bakso porsi pangsit kuah porsi
# 953571                               cake coklat blueberry
# 1117764                                 captain morgan rum
# 784130   nasi goreng ayam pedes dikit nasi goreng kambi...
# 769648                                       nasi ayam bks
# 1042152                               medicated shampoo ml
# 376465             susu kambing goat milk full cream kotak
# 448420                                       pesaman bobby
# 1166113             dendeng balado lele goreng balado nasi
# 1309996                    nasi ayam pedes bungkus kerupuk
# 954800                               nestle uk liter botol
# 12228                         nasi bebek goreng aqua besar
# 1348097                    susu lactogrow rasa vanila gram
#
#                                 real_tags  num_tags
# 453659                             {buah}         1
# 1035042                                {}         0
# 1495967                           {bunga}         1
# 55408                      {anggur merah}         1
# 1329262                                {}         0
# 1248100                                {}         0
# 924181                            {bakso}         1
# 349637         {bakso, mie ayam, pangsit}         3
# 953571                     {cokelat, kue}         2
# 1117764                                {}         0
# 784130       {kambing, nasi goreng, ayam}         3
# 769648                       {nasi, ayam}         2
# 1042152                          {shampo}         1
# 376465              {kambing, susu, krim}         3
# 448420                                 {}         0
# 1166113      {nasi, lele goreng, rendang}         3
# 1309996             {nasi, kerupuk, ayam}         3
# 954800                                 {}         0
# 12228    {bebek goreng, aqua, nasi bebek}         3
# 1348097                            {susu}         1

# %%
len(dtext2)
# Out:
# 1499625

# %% [markdown]
# ### Modeling

# %%
def hamming_score(y_true, y_pred, normalize=True, sample_weight=None):
    '''
    Compute the Hamming score (a.k.a. label-based accuracy) for the multi-label case
    http://stackoverflow.com/q/32239577/395857
    '''
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/float(len(set_true.union(set_pred)) )
        acc_list.append(tmp_a)
    return np.mean(acc_list)


def custom_loss_func2(model,X,y_true0):
    y_pred0=model.predict(X)
    return hamming_score(y_true0, y_pred0)


def print_score(y_pred, clf,y_test_tfidf):
    print("Clf: ", clf)
    print("Hamming loss: {}".format(hamming_loss(y_test_tfidf,y_pred)))
    try:
        print("Hamming score: {}".format(hamming_score(y_test_tfidf,y_pred)))
    except:
        print("Hamming score: {}".format(hamming_score(y_test_tfidf,y_pred.toarray())))
        
    print("---")    
    
def check_tag2(list_X,i):
    if i in list_X:
        return 1
    else :
        return 0

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from imblearn.over_sampling import RandomOverSampler,SMOTE
from sklearn.metrics import hamming_loss
from sklearn.preprocessing import LabelEncoder
from skmultilearn.problem_transform import LabelPowerset,ClassifierChain
from skmultilearn.adapt import MLkNN
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from gensim.models import Word2Vec
from gensim.models.wrappers import FastText
from gensim.models import KeyedVectors
from collections import defaultdict
from sklearn.preprocessing import RobustScaler

# %%
w2v_path="../../data/w2v/"

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    
    stems =[]
    for t in filtered_tokens:
        try:
            t2=stemmer.stem(t.decode("utf-8")) 
        except:
            t2=stemmer.stem(t) 
        stems.append(t2)
        
    return stems
#     return filtered_tokens

# %%
class TfidfEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.word2weight = 1
        self.dim = len(word2vec["buku"])

    def fit(self, X, y=None):
        tfidf = TfidfVectorizer(max_df=0.998, max_features=1500,min_df=0.00005, stop_words='bahasa',
                        use_idf=True, ngram_range=(1,4))
        tfidf.fit(X)
        self.tfidf=tfidf
        # if a word was never seen - it must be at least as infrequent
        # as any of the known words - so the default idf is the max of 
        # known idf's
        max_idf = max(tfidf.idf_)
        self.word2weight = defaultdict(
            lambda: max_idf,
            [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()])

        return self

    def transform(self, X):
        return np.array([
                np.mean([self.word2vec[w] * self.word2weight[w]
                         for w in words.split(" ") if w in self.word2vec] or
                        [np.zeros(self.dim)], axis=0)
                for words in X
            ])

# %%
# embd2=Word2Vec.load(w2v_path+'our_vocab.bin')
embd2=Word2Vec.load(w2v_path+'our_vocab2.bin')

# %%
len(embd2["buku"])
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# 95

# %%
## remove zero tags
dtext3=dtext2[dtext2.num_tags!=0]
dtext3.head()
# Out:
#           booking_time   order_no  voucher_id  \
# 0  2017-06-23 14:05:01  330184060         NaN
# 1  2018-08-08 10:44:44  482277109         NaN
# 3  2018-04-14 08:03:46  471187625         NaN
# 4  2018-09-05 07:45:29  484118692         NaN
# 5  2018-08-17 09:08:30  482854178         NaN
#
#                                            item_list payment_method_name  \
# 0                                     caramel coklat                CASH
# 1                    Sate Ayam (daging aja) 40 tusuk                CASH
# 3                                    krimcis duren 1              GO-PAY
# 4  pecel lele 1 ( pakai cabe ayam rica - rica)  t...                CASH
# 5                                        durian /box                CASH
#
#                                       item_list_cln1  \
# 0                                     caramel coklat
# 1                         sate ayam daging aja tusuk
# 3                                      krimcis duren
# 4  pecel lele pakai cabe ayam rica , rica tidak p...
# 5                                         durian box
#
#                                       item_list_cln2  \
# 0                                     caramel coklat
# 1                         sate ayam daging aja tusuk
# 3                                      krimcis duren
# 4  pecel lele pakai cabe ayam rica rica tidak pak...
# 5                                         durian box
#
#                   real_tags  num_tags
# 0                 {cokelat}         1
# 1       {daging, sate ayam}         2
# 3                  {durian}         1
# 4  {nasi, pecel lele, ayam}         3
# 5                  {durian}         1

# %%
len(dtext3)
# Out:
# 1091020

# %%
multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(dtext3.real_tags)
# Out:
# MultiLabelBinarizer(classes=None, sparse_output=False)

# %%
# multilabel_binarizer.classes_

# %%
train2, test2 = train_test_split(dtext3.sample(680000,random_state=231), random_state=42, test_size=0.2, shuffle=True)

X_train2=train2.item_list_cln2
X_test2=test2.item_list_cln2

Y_train2=multilabel_binarizer.transform(train2.real_tags)
Y_test2=multilabel_binarizer.transform(test2.real_tags)

# %%
# tv2 = TfidfVectorizer(max_df=0.998, max_features=1500,min_df=0.00005, stop_words='bahasa',
#                         use_idf=True, ngram_range=(1,4))
# tv2.fit(X_train2)

tv2=TfidfEmbeddingVectorizer(embd2)
tv2.fit(X_train2)
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
X_train2[225808]
# Out:
# 'sate ayam tusuklontong'

# %%
X_tr2=tv2.transform(X_train2)
X_te2=tv2.transform(X_test2)
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:25: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:25: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
scaler = RobustScaler()
scaler.fit(X_tr2)
# Out:
# RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)

# %%
X_tr2=scaler.transform(X_tr2)
X_te2=scaler.transform(X_te2)

# %%
X_tr2.shape
# Out:
# (544000, 95)

# %%
model_path
# Out:
# '../../model/modeling_second_propose/'

# %%
# nb_clf = OneVsRestClassifier(MultinomialNB())
# nb_clf2 = LabelPowerset(MultinomialNB())
# nb_clf3 = ClassifierChain(MultinomialNB())
# sgd = OneVsRestClassifier(SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=6, tol=None))
# lr = OneVsRestClassifier(LogisticRegression())
# lsv = OneVsRestClassifier(LinearSVC())
# MLk = MLkNN(k=20)
# dect = OneVsRestClassifier(DecisionTreeClassifier(max_depth=50, min_samples_split=3, min_samples_leaf=4))
# dect2 = ClassifierChain(DecisionTreeClassifier(max_depth=50, min_samples_split=3, min_samples_leaf=4))
    
clf=OneVsRestClassifier(DecisionTreeClassifier(max_depth=50, min_samples_split=3, min_samples_leaf=4),n_jobs=-1)
print("Fitting ..")
clf.fit(X_tr2, Y_train2)
print("Done!!")
print("Saving..")
joblib.dump(clf,model_path+"dectree_wv_tfidf_standarscaler.pkl")
print("Done!!")


y_pred = clf.predict(X_te2)
print_score(y_pred, clf, Y_test2)
# Out:
# Fitting ..
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 49 is present in all training examples.
#   str(classes[c]))
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/sklearn/multiclass.py:76: UserWarning: Label not 441 is present in all training examples.
#   str(classes[c]))
# Done!!
# Saving..
# Done!!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-98e912a2a466> in <module>()
#      19
#      20 y_pred = clf.predict(X_te2)
# ---> 21 print_score(y_pred, class1, Y_test2)
#
# NameError: name 'class1' is not defined

# %%
y_pred = clf.predict(X_te2)
print_score(y_pred, clf, Y_test2)
# Out:
# Clf:  OneVsRestClassifier(estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=3,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           n_jobs=-1)
# Hamming loss: 0.0031697577468487396
# Hamming score: 0.5512186466107422
# ---

# %%
## DecTree
clf2=joblib.load(model_path+"dectree_second_tags_2_680.pkl")
y_pred2=clf2.predict(X_te2)
test2["tag_pred"]=multilabel_binarizer.inverse_transform(y_pred2)

# %%
test2.sample(300).head(20)
# Out:
#                 booking_time   order_no  voucher_id  \
# 629657   2018-05-18 08:47:58  477310088         NaN
# 321247   2017-06-07 13:02:02  321835718         NaN
# 982267   2017-10-29 02:50:29  383807610         NaN
# 288352   2016-08-02 11:15:06  179576511         NaN
# 1206355  2017-11-06 04:07:58  388494134         NaN
# 1274322  2018-06-07 14:40:04  478472122         NaN
# 218280   2017-12-18 04:51:33  411272923         NaN
# 1264719  2018-05-15 16:56:44  477173654         NaN
# 1241417  2018-05-25 06:45:46  477671411         NaN
# 1025513  2018-05-13 16:51:16  477057552         NaN
# 1378786  2017-10-12 11:05:15  375731247         NaN
# 721983   2017-10-07 11:42:12  373428508         NaN
# 749739   2017-03-31 14:22:07  297993646         NaN
# 1304693  2018-05-25 11:30:37  477690036         NaN
# 1420453  2018-08-10 15:14:44  482405752         NaN
# 1060234  2017-07-28 02:22:10  344840218         NaN
# 709764   2016-05-02 11:38:24  132521271         NaN
# 35873    2017-05-10 07:35:37  311385019         NaN
# 329329   2017-10-30 04:11:32  384480553         NaN
# 570099   2018-07-13 06:59:48  480621518         NaN
#
#                                                  item_list  \
# 629657                            vitamin wajah jelly blue
# 321247   1/2 loyang kue bandung coklat keju (sedikit me...
# 982267                           cakue goreng biasa 5 biji
# 288352       Beefy cheesy chicken : 2. (1 kentang, 1 nasi)
# 1206355                  Rujak samping gramedia. Cabenya 4
# 1274322                 beli rokok evolution hijau menthol
# 218280   nasi putih 4 porsisiobak 4 porsisate plecing 2...
# 1264719                                         ketoprak 5
# 1241417    kuah bakut sayur asin 1 porsitelor pete 1 porsi
# 1025513  2 bungkus djarum super8 aqua dingin ukuran sedang
# 1378786      lele seporsi, ayam paha seporsi, nasi 2 porsi
# 721983   mie narako well : 3mie narako jahannam : 2mie ...
# 749739   Sate kambing daging saja 10 sup daging satu na...
# 1304693                                               beer
# 1420453  pampers mamypoko ukuran XXL ISI 8, DAN SUSU S2...
# 1060234  obat jerawat (1 botol), krim jerawat II (1 botol)
# 709764                    daging giling import dan pumpkin
# 35873    (pesanan ibu Citra Duren Sawit) styrofoam 10cm...
# 329329                              mie dan pangsit mentah
# 570099                                 Soup ceker 2 taro 1
#
#         payment_method_name  \
# 629657                 CASH
# 321247      PARTIAL_PAYMENT
# 982267                 CASH
# 288352                 CASH
# 1206355                CASH
# 1274322                CASH
# 218280                 CASH
# 1264719                CASH
# 1241417                CASH
# 1025513                CASH
# 1378786              GO-PAY
# 721983                 CASH
# 749739                 CASH
# 1304693     PARTIAL_PAYMENT
# 1420453                CASH
# 1060234                CASH
# 709764                 CASH
# 35873                GO-PAY
# 329329               GO-PAY
# 570099                 CASH
#
#                                             item_list_cln1  \
# 629657                            vitamin wajah jelly blue
# 321247      loyang kue bandung coklat keju sedikit mentega
# 982267                             cakue goreng biasa biji
# 288352              beefy cheesy chicken , , kentang, nasi
# 1206355                    rujak samping gramedia, cabenya
# 1274322                 beli rokok evolution hijau menthol
# 218280      nasi putih porsisiobak porsisate plecing porsi
# 1264719                                           ketoprak
# 1241417        kuah bakut sayur asin porsitelor pete porsi
# 1025513     bungkus djarum super aqua dingin ukuran sedang
# 1378786        lele seporsi, ayam paha seporsi, nasi porsi
# 721983   mie narako well , mie narako jahannam , mie na...
# 749739   sate kambing daging saja sup daging satu nasi ...
# 1304693                                               beer
# 1420453  pampers mamypoko ukuran xxl isi ,,susu s gram ...
# 1060234         obat jerawat botol , krim jerawat ii botol
# 709764                        daging giling import,pumpkin
# 35873    pesanan ibu citra duren sawit styrofoam cm tin...
# 329329                                  mie,pangsit mentah
# 570099                                     soup ceker taro
#
#                                             item_list_cln2  \
# 629657                            vitamin wajah jelly blue
# 321247      loyang kue bandung coklat keju sedikit mentega
# 982267                             cakue goreng biasa biji
# 288352                   beefy cheesy chicken kentang nasi
# 1206355                     rujak samping gramedia cabenya
# 1274322                 beli rokok evolution hijau menthol
# 218280      nasi putih porsisiobak porsisate plecing porsi
# 1264719                                           ketoprak
# 1241417        kuah bakut sayur asin porsitelor pete porsi
# 1025513     bungkus djarum super aqua dingin ukuran sedang
# 1378786          lele seporsi ayam paha seporsi nasi porsi
# 721983   mie narako well mie narako jahannam mie narako...
# 749739   sate kambing daging saja sup daging satu nasi ...
# 1304693                                               beer
# 1420453  pampers mamypoko ukuran xxl isi susu s gram tahap
# 1060234           obat jerawat botol krim jerawat ii botol
# 709764                        daging giling import pumpkin
# 35873    pesanan ibu citra duren sawit styrofoam cm tin...
# 329329                                  mie pangsit mentah
# 570099                                     soup ceker taro
#
#                                  real_tags  num_tags  \
# 629657                           {vitamin}         1
# 321247                      {cokelat, kue}         2
# 982267                             {cakue}         1
# 288352               {nasi, kentang, ayam}         3
# 1206355                            {rujak}         1
# 1274322                            {rokok}         1
# 218280                  {nasi putih, sate}         2
# 1264719                         {ketoprak}         1
# 1241417               {pete, telur, sayur}         3
# 1025513                             {aqua}         1
# 1378786            {nasi, lele, ayam paha}         3
# 721983                               {mie}         1
# 749739   {nasi, sop, daging, sate kambing}         4
# 1304693                              {bir}         1
# 1420453         {pampers, susu, mamy poko}         3
# 1060234       {krim jerawat, obat jerawat}         2
# 709764                            {daging}         1
# 35873                             {durian}         1
# 329329                      {pangsit, mie}         2
# 570099                        {sop, ceker}         2
#
#                                                   tag_pred
# 629657                                          (vitamin,)
# 321247                                          (cokelat,)
# 982267                                            (cakue,)
# 288352                                             (ayam,)
# 1206355                                      (buah, rujak)
# 1274322                                           (rokok,)
# 218280                                       (nasi putih,)
# 1264719                                        (ketoprak,)
# 1241417  (ayam, kerupuk, lontong sayur, nasi, telur asi...
# 1025513                                           (rokok,)
# 1378786                                       (lele, nasi)
# 721983                                        (mie, pizza)
# 749739                   (daging, nasi, sop, telur ceplok)
# 1304693                                             (bir,)
# 1420453                                       (mamy poko,)
# 1060234                       (krim jerawat, obat jerawat)
# 709764                                           (wortel,)
# 35873                                            (durian,)
# 329329                                      (mie, pangsit)
# 570099                                                  ()

# %%
test1=test2[["item_list_cln2","real_tags","tag_pred"]]

# %%
for c in ts:
    cek_tag=test1.real_tags.apply(lambda x : check_tag2(x,c))
    test1[c]=cek_tag
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
acc=[]
benc=[]
lrate=[]
auc_list=[]
for category in list(ts):
    # compute the testing accuracy
    True_tag=test2.real_tags.apply(lambda x: check_tag2(x,category)).as_matrix()
    Pred_tag=test2.tag_pred.apply(lambda x: check_tag2(x,category)).as_matrix()
    
    acc_score=accuracy_score(True_tag,Pred_tag)
    try:
        auc_cat=roc_auc_score(True_tag,Pred_tag)
    except:
        auc_cat=0.001
    
    print('Test accuracy is {}'.format(acc_score))
    if True_tag.mean()<0.5:
        benchm=1-test1[category].mean()
    else:
        benchm=test1[category].mean()
    print('diff with benchmark {}'.format(acc_score-benchm))
    
    acc.append(acc_score)
    benc.append(benchm)
    lrate.append(((acc_score-benchm)/float(benchm))*100)
    auc_list.append(auc_cat)
    
dFRes2=pd.DataFrame({"tags":list(ts),"accuracy":acc,"benchmark":benc,"AUC":auc_list,"learn_rate(%)":lrate})
# Out:
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/alamhanz/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Test accuracy is 0.997
# diff with benchmark 0.0031250000000000444
# Test accuracy is 0.9968455882352941
# diff with benchmark -0.0004191176470588198
# Test accuracy is 0.9967573529411765
# diff with benchmark 0.002742647058823544
# Test accuracy is 0.9924926470588236
# diff with benchmark 0.0006764705882352784
# Test accuracy is 0.9767132352941177
# diff with benchmark 0.0021838235294118213
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9981985294117647
# diff with benchmark 0.0014705882352941124
# Test accuracy is 0.9986544117647059
# diff with benchmark -0.00023529411764700026
# Test accuracy is 0.9993308823529412
# diff with benchmark -0.00016911764705884735
# Test accuracy is 0.9996911764705882
# diff with benchmark 4.411764705880561e-05
# Test accuracy is 0.9961838235294118
# diff with benchmark 0.000786764705882459
# Test accuracy is 0.9999558823529412
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9994705882352941
# diff with benchmark 0.00016176470588236125
# Test accuracy is 0.9998088235294118
# diff with benchmark 3.6764705882430526e-05
# Test accuracy is 0.9979411764705882
# diff with benchmark 7.352941176463901e-05
# Test accuracy is 0.9992279411764706
# diff with benchmark -0.00017647058823522244
# Test accuracy is 0.9890588235294118
# diff with benchmark 0.01852205882352942
# Test accuracy is 0.999875
# diff with benchmark -1.470588235297221e-05
# Test accuracy is 0.9844632352941176
# diff with benchmark 0.004154411764705879
# Test accuracy is 0.9993161764705882
# diff with benchmark 0.000286764705882403
# Test accuracy is 0.9997647058823529
# diff with benchmark 2.2058823529347293e-05
# Test accuracy is 0.99625
# diff with benchmark 0.0008382352941176396
# Test accuracy is 0.9994852941176471
# diff with benchmark 0.00013235294117652785
# Test accuracy is 0.9988161764705883
# diff with benchmark -0.00024264705882348636
# Test accuracy is 0.9998088235294118
# diff with benchmark -3.6764705882319504e-05
# Test accuracy is 0.9920588235294118
# diff with benchmark -0.0009926470588235148
# Test accuracy is 0.9977279411764706
# diff with benchmark 0.00043382352941179203
# Test accuracy is 0.9993529411764706
# diff with benchmark 0.00022058823529413907
# Test accuracy is 0.9983455882352941
# diff with benchmark 0.00020588235294116686
# Test accuracy is 0.9999558823529412
# diff with benchmark 1.470588235297221e-05
# Test accuracy is 0.9921323529411765
# diff with benchmark 0.0006911764705882506
# Test accuracy is 0.9979044117647059
# diff with benchmark 0.0006985294117647367
# Test accuracy is 0.9926323529411765
# diff with benchmark 0.001073529411764751
# Test accuracy is 0.9985367647058824
# diff with benchmark 0.00013970588235301395
# Test accuracy is 0.9989558823529412
# diff with benchmark 0.00011764705882355564
# Test accuracy is 0.9986985294117647
# diff with benchmark 0.0003750000000000142
# Test accuracy is 0.9996838235294118
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9979779411764705
# diff with benchmark 0.00016911764705873633
# Test accuracy is 0.9987058823529412
# diff with benchmark 0.0003970588235294725
# Test accuracy is 0.9952426470588235
# diff with benchmark -0.00013970588235301395
# Test accuracy is 0.9781029411764706
# diff with benchmark -0.0011764705882353343
# Test accuracy is 0.999985294117647
# diff with benchmark 0.0
# Test accuracy is 0.9950661764705883
# diff with benchmark 0.0075955882352941595
# Test accuracy is 0.999360294117647
# diff with benchmark 0.0003382352941175837
# Test accuracy is 0.9986029411764706
# diff with benchmark 0.0015955882352941542
# Test accuracy is 0.9975
# diff with benchmark 0.0030588235294117805
# Test accuracy is 0.9981985294117647
# diff with benchmark 0.0012720588235294317
# Test accuracy is 0.9982867647058824
# diff with benchmark -6.61764705881529e-05
# Test accuracy is 0.999985294117647
# diff with benchmark -1.470588235297221e-05
# Test accuracy is 0.9999117647058824
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9986544117647059
# diff with benchmark 0.0002573529411765696
# Test accuracy is 0.9996764705882353
# diff with benchmark 5.1470588235291714e-05
# Test accuracy is 0.9771617647058823
# diff with benchmark -0.0018382352941176405
# Test accuracy is 0.9984705882352941
# diff with benchmark -5.1470588235291714e-05
# Test accuracy is 0.9999338235294117
# diff with benchmark -1.470588235297221e-05
# Test accuracy is 0.9988455882352941
# diff with benchmark 0.0003529411764705559
# Test accuracy is 0.9991176470588236
# diff with benchmark -0.00011029411764706953
# Test accuracy is 0.9987794117647059
# diff with benchmark 0.004095588235294101
# Test accuracy is 0.9964779411764706
# diff with benchmark -0.0007352941176470562
# Test accuracy is 0.9990735294117647
# diff with benchmark 0.000286764705882403
# Test accuracy is 0.998375
# diff with benchmark 0.0013823529411765012
# Test accuracy is 0.996625
# diff with benchmark 0.0004485294117646532
# Test accuracy is 0.996875
# diff with benchmark -8.088235294123614e-05
# Test accuracy is 0.9991397058823529
# diff with benchmark 0.00012499999999993072
# Test accuracy is 0.9997132352941176
# diff with benchmark 5.1470588235291714e-05
# Test accuracy is 0.9988161764705883
# diff with benchmark -8.088235294112511e-05
# Test accuracy is 0.9960808823529411
# diff with benchmark 0.0011911764705881955
# Test accuracy is 0.9984411764705883
# diff with benchmark -0.0003088235294117503
# Test accuracy is 0.9989338235294117
# diff with benchmark 0.00048529411764708374
# Test accuracy is 0.9995588235294117
# diff with benchmark 0.0
# Test accuracy is 0.9996838235294118
# diff with benchmark -4.411764705880561e-05
# Test accuracy is 0.9987941176470588
# diff with benchmark -0.00017647058823533346
# Test accuracy is 0.9930882352941176
# diff with benchmark 0.0002941176470587781
# Test accuracy is 0.9872279411764706
# diff with benchmark 0.0039044117647059062
# Test accuracy is 0.9979926470588235
# diff with benchmark 4.411764705880561e-05
# Test accuracy is 0.9999779411764705
# diff with benchmark 0.0
# Test accuracy is 0.9999705882352942
# diff with benchmark -7.352941176375083e-06
# Test accuracy is 0.9712941176470589
# diff with benchmark 0.00797794117647066
# Test accuracy is 0.9969264705882352
# diff with benchmark 0.00027941176470580587
# Test accuracy is 0.9945220588235294
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.9922426470588235
# diff with benchmark 0.010485294117646982
# Test accuracy is 0.9985955882352942
# diff with benchmark 0.0016249999999999876
# Test accuracy is 0.9999191176470589
# diff with benchmark 4.411764705891663e-05
# Test accuracy is 0.9939779411764705
# diff with benchmark 0.0003382352941175837
# Test accuracy is 0.9989632352941177
# diff with benchmark 0.0011617647058823621
# Test accuracy is 0.9994852941176471
# diff with benchmark 0.0005367647058823755
# Test accuracy is 0.9992205882352941
# diff with benchmark 0.0003970588235294725
# Test accuracy is 0.9979044117647059
# diff with benchmark -0.00015441176470587514
# Test accuracy is 0.9992867647058824
# diff with benchmark 0.00041176470588244474
# Test accuracy is 0.9946838235294118
# diff with benchmark 0.0005220588235294032
# Test accuracy is 0.9961764705882353
# diff with benchmark 0.003514705882353031
# Test accuracy is 0.9998897058823529
# diff with benchmark 2.2058823529347293e-05
# Test accuracy is 0.9979411764705882
# diff with benchmark 0.000720588235294084
# Test accuracy is 0.9983382352941177
# diff with benchmark 8.823529411772224e-05
# Test accuracy is 0.9933529411764705
# diff with benchmark 0.001588235294117557
# Test accuracy is 0.9977426470588235
# diff with benchmark 0.0008235294117646674
# Test accuracy is 0.9904779411764706
# diff with benchmark 0.0020367647058823213
# Test accuracy is 0.9977720588235294
# diff with benchmark 0.0008602941176469869
# Test accuracy is 0.9999926470588235
# diff with benchmark 0.0
# Test accuracy is 0.9981911764705882
# diff with benchmark -0.00020588235294116686
# Test accuracy is 0.9999264705882352
# diff with benchmark 7.352941176375083e-06
# Test accuracy is 0.999360294117647
# diff with benchmark 0.001154411764705876
# Test accuracy is 0.9995735294117647
# diff with benchmark 0.0002720588235294308
# Test accuracy is 0.9979338235294117
# diff with benchmark 0.0003750000000000142
# Test accuracy is 0.9970294117647058
# diff with benchmark 0.0007058823529411118
# Test accuracy is 0.9973970588235294
# diff with benchmark 0.00020588235294116686
# Test accuracy is 0.994735294117647
# diff with benchmark 0.0006911764705882506
# Test accuracy is 0.9994779411764706
# diff with benchmark 0.00015441176470587514
# Test accuracy is 0.9927794117647059
# diff with benchmark 0.005404411764705852
# Test accuracy is 0.9990514705882353
# diff with benchmark 0.0008308823529411535
# Test accuracy is 0.9998308823529412
# diff with benchmark -1.470588235297221e-05
# Test accuracy is 0.9981176470588236
# diff with benchmark 0.0010294117647059453
# Test accuracy is 0.9982647058823529
# diff with benchmark 0.00019117647058819465
# Test accuracy is 0.9986176470588235
# diff with benchmark -0.0003308823529412086
# Test accuracy is 0.9967058823529412
# diff with benchmark 0.002676470588235391
# Test accuracy is 0.9981397058823529
# diff with benchmark 0.00027941176470580587
# Test accuracy is 0.9985882352941177
# diff with benchmark -0.00013970588235290293
# Test accuracy is 0.9998897058823529
# diff with benchmark 3.6764705882319504e-05
# Test accuracy is 0.9915588235294117
# diff with benchmark 0.0053602941176470464
# Test accuracy is 0.9994779411764706
# diff with benchmark 0.00012500000000004174
# Test accuracy is 0.999625
# diff with benchmark 0.00016176470588236125
# Test accuracy is 0.9993676470588235
# diff with benchmark -0.00011029411764706953
# Test accuracy is 0.983014705882353
# diff with benchmark -0.0019044117647059045
# Test accuracy is 0.999
# diff with benchmark 0.000360294117647042
# Test accuracy is 0.9935294117647059
# diff with benchmark 0.003536764705882378
# Test accuracy is 0.9979779411764705
# diff with benchmark -9.558823529420835e-05
# Test accuracy is 0.9993235294117647
# diff with benchmark 3.6764705882319504e-05
# Test accuracy is 0.9897941176470588
# diff with benchmark 0.004470588235294115
# Test accuracy is 0.9982058823529412
# diff with benchmark 0.00022058823529413907
# Test accuracy is 0.9953823529411765
# diff with benchmark -0.00016176470588236125
# Test accuracy is 0.9857573529411765
# diff with benchmark -0.00015441176470587514
# Test accuracy is 0.9947720588235294
# diff with benchmark 0.0016176470588235015
# Test accuracy is 0.9996470588235294
# diff with benchmark -0.00012499999999993072
# Test accuracy is 0.9985220588235294
# diff with benchmark -0.0002720588235294308
# Test accuracy is 0.9840220588235294
# diff with benchmark 0.013816176470588304
# Test accuracy is 0.9999632352941177
# diff with benchmark 0.0
# Test accuracy is 0.9998823529411764
# diff with benchmark -2.941176470594442e-05
# Test accuracy is 0.9998529411764706
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9974117647058823
# diff with benchmark 0.002808823529411697
# Test accuracy is 0.9987720588235294
# diff with benchmark 0.0012867647058822929
# Test accuracy is 0.9978970588235294
# diff with benchmark 0.00017647058823533346
# Test accuracy is 0.9977720588235294
# diff with benchmark 0.0006764705882352784
# Test accuracy is 0.9982794117647059
# diff with benchmark -0.00027941176470580587
# Test accuracy is 0.9993823529411765
# diff with benchmark 0.000933823529411848
# Test accuracy is 0.9939117647058824
# diff with benchmark -0.0004926470588234588
# Test accuracy is 0.9977132352941176
# diff with benchmark 0.002102941176470585
# Test accuracy is 0.9991029411764706
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.997389705882353
# diff with benchmark 0.0003823529411765003
# Test accuracy is 0.9992941176470588
# diff with benchmark 0.0006544117647058201
# Test accuracy is 0.9975588235294117
# diff with benchmark 0.0009632352941175704
# Test accuracy is 0.9986544117647059
# diff with benchmark -0.00028676470588229197
# Test accuracy is 0.9960735294117647
# diff with benchmark 0.0007058823529412228
# Test accuracy is 0.999985294117647
# diff with benchmark 0.0
# Test accuracy is 0.9987205882352941
# diff with benchmark 0.0006838235294117645
# Test accuracy is 0.9996176470588235
# diff with benchmark 0.0002647058823529447
# Test accuracy is 0.9990955882352941
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.9993235294117647
# diff with benchmark 0.0005220588235294032
# Test accuracy is 0.99875
# diff with benchmark 0.0003897058823529864
# Test accuracy is 0.9972720588235294
# diff with benchmark 0.0008455882352941257
# Test accuracy is 0.9968823529411764
# diff with benchmark -8.823529411772224e-05
# Test accuracy is 0.9989044117647059
# diff with benchmark -0.0002720588235294308
# Test accuracy is 0.999985294117647
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9940588235294118
# diff with benchmark 0.0040661764705882675
# Test accuracy is 0.9973676470588235
# diff with benchmark -0.00023529411764711128
# Test accuracy is 0.9998602941176471
# diff with benchmark 0.00016911764705884735
# Test accuracy is 0.9988897058823529
# diff with benchmark -1.470588235297221e-05
# Test accuracy is 0.9875955882352941
# diff with benchmark 0.018985294117647045
# Test accuracy is 0.9982941176470588
# diff with benchmark 0.0011691176470587372
# Test accuracy is 0.9975
# diff with benchmark 0.00415441176470599
# Test accuracy is 0.9959485294117647
# diff with benchmark 0.0007500000000000284
# Test accuracy is 0.9984779411764706
# diff with benchmark 5.1470588235291714e-05
# Test accuracy is 0.9999044117647059
# diff with benchmark 0.0
# Test accuracy is 0.9985955882352942
# diff with benchmark 0.0002500000000000835
# Test accuracy is 0.9975808823529412
# diff with benchmark 3.6764705882319504e-05
# Test accuracy is 0.9928161764705883
# diff with benchmark 0.0037058823529412255
# Test accuracy is 0.9983823529411765
# diff with benchmark 0.0006544117647059311
# Test accuracy is 0.9985588235294117
# diff with benchmark 0.0013970588235293624
# Test accuracy is 0.9932279411764706
# diff with benchmark -0.001941176470588224
# Test accuracy is 0.976735294117647
# diff with benchmark 0.009183823529411717
# Test accuracy is 0.998014705882353
# diff with benchmark 0.0003750000000000142
# Test accuracy is 0.9969632352941177
# diff with benchmark 0.004485294117647087
# Test accuracy is 0.9957573529411765
# diff with benchmark 0.012860294117647109
# Test accuracy is 0.9989411764705882
# diff with benchmark 0.00013970588235290293
# Test accuracy is 0.9955955882352941
# diff with benchmark 0.0020514705882352935
# Test accuracy is 0.9996470588235294
# diff with benchmark 0.0003897058823529864
# Test accuracy is 0.9995367647058824
# diff with benchmark -5.882352941177782e-05
# Test accuracy is 0.9983308823529412
# diff with benchmark 0.0004926470588235699
# Test accuracy is 0.9959191176470589
# diff with benchmark -0.0004411764705881671
# Test accuracy is 0.9985588235294117
# diff with benchmark -0.00015441176470587514
# Test accuracy is 0.999639705882353
# diff with benchmark 0.0006323529411764728
# Test accuracy is 0.9972867647058824
# diff with benchmark 0.0009044117647059036
# Test accuracy is 0.9970073529411765
# diff with benchmark -0.0002794117647059169
# Test accuracy is 0.996375
# diff with benchmark -0.0003235294117647225
# Test accuracy is 0.9982647058823529
# diff with benchmark -0.00018382352941170854
# Test accuracy is 0.9987205882352941
# diff with benchmark 0.00025735294117645857
# Test accuracy is 0.9993823529411765
# diff with benchmark 0.0020000000000000018
# Test accuracy is 0.9988382352941176
# diff with benchmark 0.0017794117647058627
# Test accuracy is 0.9976911764705882
# diff with benchmark -0.00013235294117641683
# Test accuracy is 0.9998602941176471
# diff with benchmark -2.2058823529347293e-05
# Test accuracy is 0.9978235294117647
# diff with benchmark 0.0003749999999999032
# Test accuracy is 0.9654705882352941
# diff with benchmark 0.002169117647058738
# Test accuracy is 0.9999926470588235
# diff with benchmark 0.0
# Test accuracy is 0.9940955882352941
# diff with benchmark -0.0008750000000000702
# Test accuracy is 0.996735294117647
# diff with benchmark 0.0010000000000000009
# Test accuracy is 0.9987426470588235
# diff with benchmark 0.0008161764705882923
# Test accuracy is 0.998735294117647
# diff with benchmark 0.0005294117647058894
# Test accuracy is 0.9980808823529411
# diff with benchmark -0.00043382352941179203
# Test accuracy is 0.998610294117647
# diff with benchmark 0.0009779411764705426
# Test accuracy is 0.9938455882352941
# diff with benchmark 0.0018897058823529322
# Test accuracy is 0.999375
# diff with benchmark 7.352941176475003e-05
# Test accuracy is 0.9973235294117647
# diff with benchmark -0.00018382352941170854
# Test accuracy is 0.9990220588235295
# diff with benchmark -5.88235294116668e-05
# Test accuracy is 0.9985294117647059
# diff with benchmark 0.001433823529411793
# Test accuracy is 0.9981323529411765
# diff with benchmark 0.0015735294117648069
# Test accuracy is 0.9978676470588236
# diff with benchmark 0.00044852941176476424
# Test accuracy is 0.9973455882352941
# diff with benchmark -0.0004264705882353059
# Test accuracy is 0.9977867647058823
# diff with benchmark -9.558823529409732e-05
# Test accuracy is 0.9998235294117647
# diff with benchmark -2.941176470594442e-05
# Test accuracy is 0.9970735294117647
# diff with benchmark 0.0016249999999999876
# Test accuracy is 0.9999705882352942
# diff with benchmark 0.0
# Test accuracy is 0.9967941176470588
# diff with benchmark -0.000647058823529445
# Test accuracy is 0.9984705882352941
# diff with benchmark 0.0002941176470587781
# Test accuracy is 0.9982426470588235
# diff with benchmark -0.00044852941176476424
# Test accuracy is 0.9991102941176471
# diff with benchmark 0.00018382352941181956
# Test accuracy is 0.9995514705882353
# diff with benchmark 0.000286764705882403
# Test accuracy is 0.9984485294117647
# diff with benchmark -0.0003750000000000142
# Test accuracy is 0.9979779411764705
# diff with benchmark 0.004742647058823435
# Test accuracy is 0.9997058823529412
# diff with benchmark -8.823529411761122e-05
# Test accuracy is 0.9986176470588235
# diff with benchmark -0.00017647058823533346
# Test accuracy is 0.9995808823529412
# diff with benchmark 8.088235294112511e-05
# Test accuracy is 0.9988823529411764
# diff with benchmark 0.00047058823529411153
# Test accuracy is 0.9991102941176471
# diff with benchmark 0.0028529411764706136
# Test accuracy is 0.9938897058823529
# diff with benchmark 0.0010588235294117787
# Test accuracy is 0.9950588235294118
# diff with benchmark -0.0005882352941176672
# Test accuracy is 0.9958602941176471
# diff with benchmark -0.0003308823529410976
# Test accuracy is 0.9996617647058823
# diff with benchmark -4.411764705891663e-05
# Test accuracy is 0.9942720588235294
# diff with benchmark 0.003323529411764725
# Test accuracy is 0.9960661764705883
# diff with benchmark 0.0011250000000000426
# Test accuracy is 0.9999558823529412
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9961323529411765
# diff with benchmark 0.0032058823529412805
# Test accuracy is 0.9989779411764705
# diff with benchmark 0.0003088235294117503
# Test accuracy is 0.9977941176470588
# diff with benchmark 0.003595588235294156
# Test accuracy is 0.998735294117647
# diff with benchmark 0.0012352941176470011
# Test accuracy is 0.9965882352941177
# diff with benchmark 0.0006176470588235006
# Test accuracy is 0.9984632352941176
# diff with benchmark -0.00012500000000004174
# Test accuracy is 0.9987573529411765
# diff with benchmark 0.0006397058823529589
# Test accuracy is 0.9999338235294117
# diff with benchmark 0.0
# Test accuracy is 0.9954852941176471
# diff with benchmark -0.00022058823529413907
# Test accuracy is 0.9995588235294117
# diff with benchmark 0.0013088235294117512
# Test accuracy is 0.9999117647058824
# diff with benchmark 5.1470588235291714e-05
# Test accuracy is 0.9988161764705883
# diff with benchmark 0.0022132352941176547
# Test accuracy is 0.9925808823529412
# diff with benchmark 0.0023602941176470438
# Test accuracy is 0.9999191176470589
# diff with benchmark 2.2058823529458316e-05
# Test accuracy is 0.9998602941176471
# diff with benchmark 0.0
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9974485294117647
# diff with benchmark 0.0007867647058823479
# Test accuracy is 0.9937058823529412
# diff with benchmark 2.2058823529458316e-05
# Test accuracy is 0.9964264705882353
# diff with benchmark -0.0010661764705882648
# Test accuracy is 0.9999117647058824
# diff with benchmark 0.0
# Test accuracy is 0.9986838235294118
# diff with benchmark -0.00017647058823533346
# Test accuracy is 0.9994044117647058
# diff with benchmark 0.00028676470588229197
# Test accuracy is 0.9984852941176471
# diff with benchmark 0.002161764705882363
# Test accuracy is 0.9993529411764706
# diff with benchmark 0.0004411764705881671
# Test accuracy is 0.9997279411764706
# diff with benchmark 0.0
# Test accuracy is 0.9978676470588236
# diff with benchmark 0.0026397058823529607
# Test accuracy is 0.9992426470588235
# diff with benchmark 0.0
# Test accuracy is 0.9982426470588235
# diff with benchmark 0.0006102941176470145
# Test accuracy is 0.9978602941176471
# diff with benchmark 0.0013088235294117512
# Test accuracy is 0.9942867647058824
# diff with benchmark 0.0011397058823530148
# Test accuracy is 0.9995808823529412
# diff with benchmark -0.00014705882352938904
# Test accuracy is 0.9988014705882353
# diff with benchmark 0.00015441176470587514
# Test accuracy is 0.9896029411764706
# diff with benchmark 0.0003382352941176947
# Test accuracy is 0.9998161764705882
# diff with benchmark 9.558823529409732e-05
# Test accuracy is 0.9993088235294117
# diff with benchmark -0.00012500000000004174
# Test accuracy is 0.9984852941176471
# diff with benchmark -0.00027941176470580587
# Test accuracy is 0.9910588235294118
# diff with benchmark 0.0028529411764706136
# Test accuracy is 0.9968529411764706
# diff with benchmark 0.00018382352941181956
# Test accuracy is 0.9996691176470588
# diff with benchmark 0.0007058823529411118
# Test accuracy is 0.9987426470588235
# diff with benchmark 0.005323529411764727
# Test accuracy is 0.9981029411764706
# diff with benchmark -9.558823529409732e-05
# Test accuracy is 0.9972352941176471
# diff with benchmark -7.352941176375083e-06
# Test accuracy is 0.9985588235294117
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.9982647058823529
# diff with benchmark 0.0006544117647059311
# Test accuracy is 0.9984485294117647
# diff with benchmark 0.0006985294117646257
# Test accuracy is 0.9988823529411764
# diff with benchmark 5.882352941177782e-05
# Test accuracy is 0.9982205882352941
# diff with benchmark 0.0012720588235294317
# Test accuracy is 0.9987941176470588
# diff with benchmark 6.617647058826392e-05
# Test accuracy is 0.9986911764705882
# diff with benchmark -0.00025735294117645857
# Test accuracy is 0.9985588235294117
# diff with benchmark -0.00011764705882355564
# Test accuracy is 0.9979558823529412
# diff with benchmark -0.000360294117647042
# Test accuracy is 0.9965808823529412
# diff with benchmark 0.00018382352941181956
# Test accuracy is 0.9988235294117647
# diff with benchmark 9.558823529409732e-05
# Test accuracy is 0.9989191176470589
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9988676470588236
# diff with benchmark 0.0002500000000000835
# Test accuracy is 0.9972058823529412
# diff with benchmark -0.0005882352941176672
# Test accuracy is 0.9983823529411765
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9980588235294118
# diff with benchmark 0.0011029411764705843
# Test accuracy is 0.9987720588235294
# diff with benchmark 0.0
# Test accuracy is 0.996639705882353
# diff with benchmark -0.0007720588235293757
# Test accuracy is 0.9972720588235294
# diff with benchmark 0.0035073529411764337
# Test accuracy is 0.9992867647058824
# diff with benchmark 0.00011029411764706953
# Test accuracy is 0.9976764705882353
# diff with benchmark -0.00019117647058830567
# Test accuracy is 0.9984705882352941
# diff with benchmark 0.00114705882352939
# Test accuracy is 0.9998235294117647
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.99725
# diff with benchmark 0.0034264705882353086
# Test accuracy is 0.9997205882352941
# diff with benchmark -3.6764705882430526e-05
# Test accuracy is 0.9959485294117647
# diff with benchmark 0.002507352941176433
# Test accuracy is 0.9978602941176471
# diff with benchmark 0.0008750000000000702
# Test accuracy is 0.9916911764705882
# diff with benchmark 0.00408088235294124
# Test accuracy is 0.9995367647058824
# diff with benchmark 0.0006911764705882506
# Test accuracy is 0.9945073529411764
# diff with benchmark 0.0026397058823528496
# Test accuracy is 0.9994485294117647
# diff with benchmark -0.00012500000000004174
# Test accuracy is 0.9916029411764706
# diff with benchmark -0.002095588235294099
# Test accuracy is 0.994389705882353
# diff with benchmark 0.0008235294117647785
# Test accuracy is 0.965125
# diff with benchmark 0.0018602941176470988
# Test accuracy is 0.9977279411764706
# diff with benchmark 0.0010588235294117787
# Test accuracy is 0.9985367647058824
# diff with benchmark 0.0010220588235294592
# Test accuracy is 0.9943455882352941
# diff with benchmark -0.00019852941176479177
# Test accuracy is 0.9984411764705883
# diff with benchmark 8.823529411772224e-05
# Test accuracy is 0.9975294117647059
# diff with benchmark 0.004463235294117629
# Test accuracy is 0.9983970588235294
# diff with benchmark -8.823529411772224e-05
# Test accuracy is 0.999625
# diff with benchmark 0.0003897058823528754
# Test accuracy is 0.9976176470588235
# diff with benchmark 0.0008529411764706119
# Test accuracy is 0.9998455882352941
# diff with benchmark 7.352941176486105e-06
# Test accuracy is 0.9927794117647059
# diff with benchmark 0.0013308823529410985
# Test accuracy is 0.9985661764705882
# diff with benchmark -0.0002794117647059169
# Test accuracy is 0.999875
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.999985294117647
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9974117647058823
# diff with benchmark 0.0009632352941175704
# Test accuracy is 0.9996323529411765
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.9945514705882353
# diff with benchmark 0.0014705882352941124
# Test accuracy is 0.9991397058823529
# diff with benchmark -0.0003088235294117503
# Test accuracy is 0.9803823529411765
# diff with benchmark 0.014139705882352915
# Test accuracy is 0.9979338235294117
# diff with benchmark 0.0012647058823529456
# Test accuracy is 0.9998235294117647
# diff with benchmark -2.941176470594442e-05
# Test accuracy is 0.9995808823529412
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.9997720588235294
# diff with benchmark -5.882352941177782e-05
# Test accuracy is 0.9982720588235294
# diff with benchmark 0.0017573529411765154
# Test accuracy is 0.994389705882353
# diff with benchmark 0.0006029411764706394
# Test accuracy is 0.9964044117647058
# diff with benchmark 0.0004485294117646532
# Test accuracy is 0.9916838235294118
# diff with benchmark -0.0008014705882353201
# Test accuracy is 0.9992720588235294
# diff with benchmark 6.617647058826392e-05
# Test accuracy is 0.9986691176470588
# diff with benchmark 0.00020588235294116686
# Test accuracy is 0.9998014705882353
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.9982647058823529
# diff with benchmark -0.00013970588235290293
# Test accuracy is 0.9929044117647059
# diff with benchmark 0.004220588235294143
# Test accuracy is 0.996014705882353
# diff with benchmark 0.0004264705882353059
# Test accuracy is 0.999735294117647
# diff with benchmark 0.0003382352941176947
# Test accuracy is 0.997389705882353
# diff with benchmark 0.0011250000000000426
# Test accuracy is 0.9918897058823529
# diff with benchmark 0.00019117647058819465
# Test accuracy is 0.9993382352941177
# diff with benchmark -3.6764705882319504e-05
# Test accuracy is 0.9994779411764706
# diff with benchmark -7.352941176475003e-05
# Test accuracy is 0.999985294117647
# diff with benchmark 0.0
# Test accuracy is 0.9999191176470589
# diff with benchmark -7.352941176375083e-06
# Test accuracy is 0.9972720588235294
# diff with benchmark 0.0013088235294117512
# Test accuracy is 0.9991397058823529
# diff with benchmark -0.00011764705882355564
# Test accuracy is 0.9961691176470588
# diff with benchmark 0.001875000000000071
# Test accuracy is 0.9985735294117647
# diff with benchmark 0.0020000000000000018
# Test accuracy is 0.9980367647058823
# diff with benchmark 0.0009558823529411953
# Test accuracy is 0.9987647058823529
# diff with benchmark 0.0005147058823529171
# Test accuracy is 0.9992720588235294
# diff with benchmark 0.00022058823529413907
# Test accuracy is 0.9999191176470589
# diff with benchmark 0.0
# Test accuracy is 0.9988823529411764
# diff with benchmark 0.0008455882352941257
# Test accuracy is 0.9952279411764706
# diff with benchmark -0.0007499999999999174
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9987794117647059
# diff with benchmark 0.0015220588235294041
# Test accuracy is 0.9984705882352941
# diff with benchmark -8.088235294123614e-05
# Test accuracy is 0.9998161764705882
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.9970955882352941
# diff with benchmark 0.00021323529411765296
# Test accuracy is 0.999875
# diff with benchmark 2.94117647058334e-05
# Test accuracy is 0.99925
# diff with benchmark 7.352941176463901e-05
# Test accuracy is 0.9999485294117647
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9961470588235294
# diff with benchmark 0.004602941176470532
# Test accuracy is 0.9974044117647058
# diff with benchmark 0.0004485294117646532
# Test accuracy is 0.9985808823529412
# diff with benchmark 0.00022058823529413907
# Test accuracy is 0.9971764705882353
# diff with benchmark 0.0005514705882353477
# Test accuracy is 0.997625
# diff with benchmark -6.617647058826392e-05
# Test accuracy is 0.9985220588235294
# diff with benchmark 0.00048529411764708374
# Test accuracy is 0.9978897058823529
# diff with benchmark -7.352941176475003e-05
# Test accuracy is 0.9984705882352941
# diff with benchmark 0.0013455882352940707
# Test accuracy is 0.9991544117647059
# diff with benchmark 0.0007867647058823479
# Test accuracy is 0.9979338235294117
# diff with benchmark 0.0023308823529410994
# Test accuracy is 0.9985073529411764
# diff with benchmark 0.0024117647058823355
# Test accuracy is 0.9998014705882353
# diff with benchmark 0.0
# Test accuracy is 0.9976029411764706
# diff with benchmark -0.00011764705882344462
# Test accuracy is 0.9970367647058823
# diff with benchmark 0.0018161764705881822
# Test accuracy is 0.9904705882352941
# diff with benchmark -0.0007058823529412228
# Test accuracy is 0.9992720588235294
# diff with benchmark 0.0012132352941176539
# Test accuracy is 0.9993823529411765
# diff with benchmark 0.00021323529411765296
# Test accuracy is 0.9993161764705882
# diff with benchmark 0.001867647058823474
# Test accuracy is 0.9994264705882353
# diff with benchmark 0.0004191176470588198
# Test accuracy is 0.9982426470588235
# diff with benchmark -0.0003823529411765003
# Test accuracy is 0.9966323529411765
# diff with benchmark -0.0002647058823529447
# Test accuracy is 0.9973823529411765
# diff with benchmark -0.00025735294117645857
# Test accuracy is 0.9967426470588235
# diff with benchmark 0.0015514705882353486
# Test accuracy is 0.9996544117647059
# diff with benchmark -2.94117647058334e-05
# Test accuracy is 0.9996985294117647
# diff with benchmark 0.00015441176470587514
# Test accuracy is 0.9712058823529411
# diff with benchmark 0.00302205882352935
# Test accuracy is 0.9993823529411765
# diff with benchmark 0.00012500000000004174
# Test accuracy is 0.9989191176470589
# diff with benchmark 0.001007352941176487
# Test accuracy is 0.9263382352941176
# diff with benchmark -0.003676470588235281
# Test accuracy is 0.9982426470588235
# diff with benchmark 0.0011911764705881955
# Test accuracy is 0.9989338235294117
# diff with benchmark 8.088235294112511e-05
# Test accuracy is 0.9992573529411765
# diff with benchmark 0.0004044117647058476
# Test accuracy is 0.9994485294117647
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.9999117647058824
# diff with benchmark 0.0
# Test accuracy is 0.9956764705882353
# diff with benchmark 0.0010588235294117787
# Test accuracy is 0.9798455882352941
# diff with benchmark 0.01444117647058818
# Test accuracy is 0.9991764705882353
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9978602941176471
# diff with benchmark 0.00018382352941181956
# Test accuracy is 0.9276544117647059
# diff with benchmark 0.008389705882352883
# Test accuracy is 0.9968088235294118
# diff with benchmark 0.0004264705882353059
# Test accuracy is 0.998735294117647
# diff with benchmark 0.0013897058823529873
# Test accuracy is 0.9970882352941176
# diff with benchmark -0.0003014705882353752
# Test accuracy is 0.9999779411764705
# diff with benchmark 0.0
# Test accuracy is 0.9991029411764706
# diff with benchmark -0.00010294117647058343
# Test accuracy is 0.9998676470588236
# diff with benchmark 7.352941176475003e-05
# Test accuracy is 0.9979632352941177
# diff with benchmark 0.0019705882352941684
# Test accuracy is 0.9999926470588235
# diff with benchmark 0.0
# Test accuracy is 0.9987058823529412
# diff with benchmark 0.00013970588235301395
# Test accuracy is 0.9987205882352941
# diff with benchmark 0.00025735294117645857
# Test accuracy is 0.9979558823529412
# diff with benchmark 0.00025735294117645857
# Test accuracy is 0.9990882352941176
# diff with benchmark 0.0008455882352941257
# Test accuracy is 0.9976176470588235
# diff with benchmark -0.00043382352941179203
# Test accuracy is 0.9994558823529411
# diff with benchmark 0.0008088235294116952
# Test accuracy is 0.9985955882352942
# diff with benchmark -2.94117647058334e-05
# Test accuracy is 0.9976691176470588
# diff with benchmark 0.0006397058823529589
# Test accuracy is 0.998014705882353
# diff with benchmark 0.002088235294117724
# Test accuracy is 0.9998823529411764
# diff with benchmark -7.352941176486105e-06
# Test accuracy is 0.9977941176470588
# diff with benchmark 0.0006838235294117645
# Test accuracy is 0.9994191176470588
# diff with benchmark 0.0003308823529412086
# Test accuracy is 0.9851544117647059
# diff with benchmark 0.0012132352941176539
# Test accuracy is 0.991625
# diff with benchmark 0.0024926470588234606
# Test accuracy is 0.9995
# diff with benchmark 0.00020588235294127788
# Test accuracy is 0.9924117647058823
# diff with benchmark 0.006772058823529381
# Test accuracy is 0.9987794117647059
# diff with benchmark 0.00046323529411762543
# Test accuracy is 0.9980294117647058
# diff with benchmark -0.00011029411764706953
# Test accuracy is 0.9987279411764706
# diff with benchmark 0.00023529411764700026
# Test accuracy is 0.9853088235294117
# diff with benchmark 0.0004117647058823337
# Test accuracy is 0.9986029411764706
# diff with benchmark 0.00012500000000004174
# Test accuracy is 0.999735294117647
# diff with benchmark -3.6764705882319504e-05
# Test accuracy is 0.9987058823529412
# diff with benchmark -9.558823529409732e-05
# Test accuracy is 0.9982867647058824
# diff with benchmark -0.000433823529411681
# Test accuracy is 1.0
# diff with benchmark 0.0
# Test accuracy is 0.9992426470588235
# diff with benchmark 0.00013970588235290293
# Test accuracy is 0.9997205882352941
# diff with benchmark 0.0002941176470587781
# Test accuracy is 0.9998897058823529
# diff with benchmark 4.411764705880561e-05
# Test accuracy is 0.9965661764705882
# diff with benchmark -2.2058823529458316e-05
# Test accuracy is 0.9986691176470588
# diff with benchmark 0.0004044117647058476
# Test accuracy is 0.998375
# diff with benchmark 0.0031838235294118222
# Test accuracy is 0.9931617647058824
# diff with benchmark 0.0015735294117646959

# %%
dFRes2["learn_rate(%)"].describe()
# Out:
# count    451.000000
# mean       0.090442
# std        0.231875
# min       -0.395313
# 25%       -0.002216
# 50%        0.020627
# 75%        0.100687
# max        1.960055
# Name: learn_rate(%), dtype: float64

# %%
dFRes2["accuracy"].describe()
# Out:
# count    451.000000
# mean       0.996851
# std        0.006440
# min        0.926338
# 25%        0.997018
# 50%        0.998471
# 75%        0.999353
# max        1.000000
# Name: accuracy, dtype: float64

# %%
dFRes2["AUC"].describe()
# Out:
# count    451.000000
# mean       0.707284
# std        0.123865
# min        0.001000
# 25%        0.648067
# 50%        0.716729
# 75%        0.784646
# max        0.935547
# Name: AUC, dtype: float64

# %%
dFRes2.sample(100).head(15)
# Out:
#             tags  accuracy  benchmark       AUC  learn_rate(%)
# 92       bintang  0.997941   0.997221  0.750984       0.072260
# 337     ketoprak  0.998272   0.996515  0.844612       0.176350
# 34      ayam pop  0.998956   0.998838  0.737125       0.011778
# 175   roti bakar  0.998382   0.997728  0.766710       0.065590
# 290    soto ayam  0.996581   0.996397  0.698352       0.018449
# 329     tremenza  0.999632   0.999654  0.680778      -0.002207
# 215   ikan bakar  0.997346   0.997772  0.647970      -0.042742
# 12        kemeja  0.999471   0.999309  0.744593       0.016188
# 231  royal canin  0.999110   0.996257  0.928114       0.286366
# 334      degirol  0.999824   0.999853  0.549978      -0.002942
# 236        bakmi  0.994272   0.990949  0.790646       0.335389
# 247      tongkol  0.995485   0.995706  0.658449      -0.022154
# 426   sabun muka  0.997669   0.997029  0.780424       0.064161
# 327   minyak gpu  0.999985   0.999993  0.499996      -0.000735
# 28        sendok  0.998346   0.998140  0.685528       0.020627

# %%
# ', '.join(dFRes2[dFRes2.AUC<=0.8].tags.tolist())

# %%
(dFRes2.AUC>0.8).mean()*415
# Out:
# 85.57649667405765

# %%
# test1[test1["rujak kuah"]==1][["item_list_cln2","real_tags"]]

# %%
# dFRes2[dFRes2.AUC<0.8].tags.tolist()
